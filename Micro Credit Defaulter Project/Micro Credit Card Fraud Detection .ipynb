# %% [markdown]
# # Credit Card Fruad Detection

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on. Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
#
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
#
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
#
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
#
# They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days.
#
# For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
#
# The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.

# %% [markdown]
# ### Goal:

# %% [markdown]
# Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Micro_Credit_Card_Project_DataFile.csv')
pd.set_option("display.max_columns",None)
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 0         220.13    260.13                2.0                0.0
# 1        3691.26   3691.26               20.0                0.0
# 2         900.13    900.13                3.0                0.0
# 3         159.42    159.42               41.0                0.0
# 4        1098.90   1098.90                4.0                0.0
# ...          ...       ...                ...                ...
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2          21.0             3078.0
# 1                   5787              1           0.0             5787.0
# 2                   1539              1           0.0             1539.0
# 3                    947              0           0.0                0.0
# 4                   2309              7           2.0            20029.0
# ...                  ...            ...           ...                ...
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 0                     1539.0                  7.50              2
# 1                     5787.0                 61.04              1
# 2                     1539.0                 66.32              1
# 3                        0.0                  0.00              1
# 4                     2309.0                 29.00              8
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0                 21               3078                1539.0
# 1                  0               5787                5787.0
# 2                  0               1539                1539.0
# 3                  0                947                 947.0
# 4                  2              23496                2888.0
# ...              ...                ...                   ...
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 0                       7.50            0.0           0.0              0
# 1                      61.04            0.0           0.0              0
# 2                      66.32            0.0           0.0              0
# 3                       2.50            0.0           0.0              0
# 4                      35.00            0.0           0.0              0
# ...                      ...            ...           ...            ...
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0                  0            2            12              6.0
# 1                  0            1            12             12.0
# 2                  0            1             6              6.0
# 3                  0            2            12              6.0
# 4                  0            7            42              6.0
# ...              ...          ...           ...              ...
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                      0.0          2.0            12                6
# 1                      0.0          1.0            12               12
# 2                      0.0          1.0             6                6
# 3                      0.0          2.0            12                6
# 4                      0.0          7.0            42                6
# ...                    ...          ...           ...              ...
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                      0.0  29.000000  29.000000     UPW  2016-07-20
# 1                      0.0   0.000000   0.000000     UPW  2016-08-10
# 2                      0.0   0.000000   0.000000     UPW  2016-08-19
# 3                      0.0   0.000000   0.000000     UPW  2016-06-06
# 4                      0.0   2.333333   2.333333     UPW  2016-06-22
# ...                    ...        ...        ...     ...         ...
# 209588                 0.0   1.000000   1.000000     UPW  2016-06-17
# 209589                 0.0   1.000000   1.000000     UPW  2016-06-12
# 209590                 0.0   4.000000   3.833333     UPW  2016-07-29
# 209591                 0.0   0.000000  10.500000     UPW  2016-07-25
# 209592                 0.0   0.000000   0.000000     UPW  2016-07-07
#
# [209593 rows x 37 columns]

# %%
#checking how long our dataset is
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# Our dataset has 209593 rows and 37 columns including target.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# ### About the columns:

# %% [markdown]
# ##### Target:
# - label :- Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}

# %% [markdown]
# ##### Features:
# - msisdn :- mobile number of user
# - aon :- age on cellular network in days
# - daily_decr30 :- Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# - daily_decr90 :- Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
# - rental30 :- Average main account balance over last 30 days
# - rental90 :- Average main account balance over last 90 days
# - last_rech_date_ma :- Number of days till last recharge of main account
# - last_rech_date_da :- Number of days till last recharge of data account
# - last_rech_amt_ma :- Amount of last recharge of main account (in Indonesian Rupiah)
# - cnt_ma_rech30 :- Number of times main account got recharged in last 30 days
# - fr_ma_rech30 :- Frequency of main account recharged in last 30 days
# - sumamnt_ma_rech30 :- Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
# - medianamnt_ma_rech30 :- Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
# - medianmarechprebal30 :- Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
# - cnt_ma_rech90 :- Number of times main account got recharged in last 90 days
# - fr_ma_rech90 :- Frequency of main account recharged in last 90 days
# - sumamnt_ma_rech90 :- Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
# - medianamnt_ma_rech90 :- Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
# - medianmarechprebal90 :- Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
# - cnt_da_rech30 :- Number of times data account got recharged in last 30 days
# - fr_da_rech30 :- Frequency of data account recharged in last 30 days
# - cnt_da_rech90 :- Number of times data account got recharged in last 90 days
# - fr_da_rech90 :- Frequency of data account recharged in last 90 days
# - cnt_loans30 :- Number of loans taken by user in last 30 days
# - amnt_loans30 :- Total amount of loans taken by user in last 30 days
# - maxamnt_loans30 :- maximum amount of loan taken by the user in last 30 days
# - medianamnt_loans30 :- Median of amounts of loan taken by the user in last 30 days
# - cnt_loans90 :- Number of loans taken by user in last 90 days
# - amnt_loans90 :- Total amount of loans taken by user in last 90 days
# - maxamnt_loans90 :- maximum amount of loan taken by the user in last 90 days
# - medianamnt_loans90 :- Median of amounts of loan taken by the user in last 90 days
# - payback30 :- Average payback time in days over last 30 days
# - payback90 :- Average payback time in days over last 90 days
# - pcircle :- telecom circle
# - pdate :- date of purchasing

# %%
#Checking the type of features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
#  14  medianamnt_ma_rech30  209593 non-null  float64
#  15  medianmarechprebal30  209593 non-null  float64
#  16  cnt_ma_rech90         209593 non-null  int64
#  17  fr_ma_rech90          209593 non-null  int64
#  18  sumamnt_ma_rech90     209593 non-null  int64
#  19  medianamnt_ma_rech90  209593 non-null  float64
#  20  medianmarechprebal90  209593 non-null  float64
#  21  cnt_da_rech30         209593 non-null  float64
#  22  fr_da_rech30          209593 non-null  float64
#  23  cnt_da_rech90         209593 non-null  int64
#  24  fr_da_rech90          209593 non-null  int64
#  25  cnt_loans30           209593 non-null  int64
#  26  amnt_loans30          209593 non-null  int64
#  27  maxamnt_loans30       209593 non-null  float64
#  28  medianamnt_loans30    209593 non-null  float64
#  29  cnt_loans90           209593 non-null  float64
#  30  amnt_loans90          209593 non-null  int64
#  31  maxamnt_loans90       209593 non-null  int64
#  32  medianamnt_loans90    209593 non-null  float64
#  33  payback30             209593 non-null  float64
#  34  payback90             209593 non-null  float64
#  35  pcircle               209593 non-null  object
#  36  pdate                 209593 non-null  object
# dtypes: float64(21), int64(13), object(3)
# memory usage: 59.2+ MB

# %% [markdown]
# - Seems there are no missing value present in my dataset.
# - Our dataset is a mixture of different types of data, there are object data, float data, int data present.
# - Last feature Pdate is object data type because it is kind of date. We will extract date,month,year from this pdate feature for better understanding.

# %% [markdown]
# ### Statiscal Summary of DataSet:

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# 25%        42.692000     280.420000     300.260000           1.000000
# 50%      1500.000000    1083.570000    1334.000000           3.000000
# 75%      7802.790000    3356.940000    4201.790000           7.000000
# max    320630.000000  198926.110000  200148.110000      998650.377733
#
#        last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  \
# count      209593.000000     209593.000000  209593.000000  209593.000000
# mean         3712.202921       2064.452797       3.978057    3737.355121
# std         53374.833430       2370.786034       4.256090   53643.625172
# min           -29.000000          0.000000       0.000000       0.000000
# 25%             0.000000        770.000000       1.000000       0.000000
# 50%             0.000000       1539.000000       3.000000       2.000000
# 75%             0.000000       2309.000000       5.000000       6.000000
# max        999171.809410      55000.000000     203.000000  999606.368132
#
#        sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# count      209593.000000         209593.000000         209593.000000
# mean         7704.501157           1812.817952           3851.927942
# std         10139.621714           2070.864620          54006.374433
# min             0.000000              0.000000           -200.000000
# 25%          1540.000000            770.000000             11.000000
# 50%          4628.000000           1539.000000             33.900000
# 75%         10010.000000           1924.000000             83.000000
# max        810096.000000          55000.000000         999479.419319
#
#        cnt_ma_rech90   fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count   209593.00000  209593.000000      209593.000000         209593.000000
# mean         6.31543       7.716780       12396.218352           1864.595821
# std          7.19347      12.590251       16857.793882           2081.680664
# min          0.00000       0.000000           0.000000              0.000000
# 25%          2.00000       0.000000        2317.000000            773.000000
# 50%          4.00000       2.000000        7226.000000           1539.000000
# 75%          8.00000       8.000000       16000.000000           1924.000000
# max        336.00000      88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# 25%               14.600000       0.000000       0.000000       0.000000
# 50%               36.000000       0.000000       0.000000       0.000000
# 75%               79.310000       0.000000       0.000000       0.000000
# max            41456.500000   99914.441420  999809.240107      38.000000
#
#         fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean        0.045712       2.758981      17.952021       274.658747
# std         0.951386       2.554502      17.379741      4245.264648
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       1.000000       6.000000         6.000000
# 50%         0.000000       2.000000      12.000000         6.000000
# 75%         0.000000       4.000000      24.000000         6.000000
# max        64.000000      50.000000     306.000000     99864.560864
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90
# count       209593.000000  209593.000000  209593.000000
# mean             0.046077       3.398826       4.321485
# std              0.200692       8.813729      10.308108
# min              0.000000       0.000000       0.000000
# 25%              0.000000       0.000000       0.000000
# 50%              0.000000       0.000000       1.666667
# 75%              0.000000       3.750000       4.500000
# max              3.000000     171.500000     171.500000

# %% [markdown]
# - Unnamed:0 feature is a kind of serial number , so it is not related with target variable, we will delete in further steps.
# - Some features like aon, daily_decr30, daily_decr90,rental30,last_rech-date_ma,last_rech_amt_ma,cnt_ma_rech30, fr_ma_rech30 and many more features have not appropriate distributed data, i.e. that the difference between min value and max value is very high. It is not in acceptable range. we will handle it later.
# - Some features have high standard deviation than it's mean value, which is not accpetable.

# %%
#checking the correlation
df.corr()
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# medianamnt_ma_rech30   -0.001371  0.141490  0.004306      0.295356
# medianmarechprebal30    0.001258 -0.004829  0.003930     -0.001153
# cnt_ma_rech90           0.002329  0.236392 -0.002725      0.587338
# fr_ma_rech90           -0.000249  0.084385  0.004401     -0.078299
# sumamnt_ma_rech90       0.000523  0.205793  0.001011      0.762981
# medianamnt_ma_rech90   -0.000298  0.120855  0.004909      0.257847
# medianmarechprebal90   -0.001947  0.039300 -0.000859      0.037495
# cnt_da_rech30           0.000888  0.003827  0.001564      0.000700
# fr_da_rech30           -0.002504 -0.000027  0.000892     -0.001499
# cnt_da_rech90          -0.001324  0.002999  0.001121      0.038814
# fr_da_rech90           -0.002827 -0.005418  0.005395      0.020673
# cnt_loans30             0.001725  0.196283 -0.001826      0.366116
# amnt_loans30            0.002387  0.197272 -0.001726      0.471492
# maxamnt_loans30         0.000698  0.000248 -0.002764     -0.000028
# medianamnt_loans30     -0.002005  0.044589  0.004664     -0.011610
# cnt_loans90             0.002241  0.004733 -0.000611      0.008962
# amnt_loans90            0.000781  0.199788 -0.002319      0.563496
# maxamnt_loans90         0.001742  0.084144 -0.001191      0.400199
# medianamnt_loans90     -0.002615  0.035747  0.002771     -0.037305
# payback30              -0.000040  0.048336  0.001940      0.026915
# payback90               0.002411  0.049183  0.002203      0.047175
#
#                       daily_decr90  rental30  rental90  last_rech_date_ma  \
# Unnamed: 0                0.003077 -0.003906 -0.003459          -0.001853
# label                     0.166150  0.058085  0.075521           0.003728
# aon                       0.000374 -0.000960 -0.000790           0.001692
# daily_decr30              0.977704  0.442066  0.458977           0.000487
# daily_decr90              1.000000  0.434685  0.471730           0.000908
# rental30                  0.434685  1.000000  0.955237          -0.001095
# rental90                  0.471730  0.955237  1.000000          -0.001688
# last_rech_date_ma         0.000908 -0.001095 -0.001688           1.000000
# last_rech_date_da        -0.001886  0.003261  0.002794           0.001790
# last_rech_amt_ma          0.264131  0.127271  0.121416          -0.000147
# cnt_ma_rech30             0.426707  0.233343  0.230260           0.004311
# fr_ma_rech30             -0.000343 -0.001219 -0.000503          -0.001629
# sumamnt_ma_rech30         0.603886  0.272649  0.259709           0.002105
# medianamnt_ma_rech30      0.282960  0.129853  0.120242          -0.001358
# medianmarechprebal30     -0.000746 -0.001415 -0.001237           0.004071
# cnt_ma_rech90             0.593069  0.312118  0.345293           0.004263
# fr_ma_rech90             -0.079530 -0.033530 -0.036524           0.001414
# sumamnt_ma_rech90         0.768817  0.342306  0.360601           0.002243
# medianamnt_ma_rech90      0.250518  0.110356  0.103151          -0.000726
# medianmarechprebal90      0.036382  0.027170  0.029547          -0.001086
# cnt_da_rech30             0.000661 -0.001105 -0.000548          -0.003467
# fr_da_rech30             -0.001570 -0.002558 -0.002345          -0.003626
# cnt_da_rech90             0.031155  0.072255  0.056282          -0.003538
# fr_da_rech90              0.016437  0.046761  0.036886          -0.002395
# cnt_loans30               0.340387  0.180203  0.171595           0.001193
# amnt_loans30              0.447869  0.233453  0.231906           0.000903
# maxamnt_loans30           0.000025 -0.000864 -0.001411           0.000928
# medianamnt_loans30       -0.005591 -0.016482 -0.009467           0.001835
# cnt_loans90               0.009446  0.004012  0.005141          -0.000225
# amnt_loans90              0.567204  0.298943  0.327436           0.000870
# maxamnt_loans90           0.397251  0.234211  0.251029          -0.001123
# medianamnt_loans90       -0.034686 -0.035489 -0.034122           0.002771
# payback30                 0.019400  0.072974  0.067110          -0.002233
# payback90                 0.040800  0.095147  0.099501          -0.001583
#
#                       last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# Unnamed: 0                    -0.001133         -0.001064       0.003320
# label                          0.001711          0.131804       0.237331
# aon                           -0.001693          0.004256      -0.003148
# daily_decr30                  -0.001636          0.275837       0.451385
# daily_decr90                  -0.001886          0.264131       0.426707
# rental30                       0.003261          0.127271       0.233343
# rental90                       0.002794          0.121416       0.230260
# last_rech_date_ma              0.001790         -0.000147       0.004311
# last_rech_date_da              1.000000         -0.000149       0.001549
# last_rech_amt_ma              -0.000149          1.000000      -0.002662
# cnt_ma_rech30                  0.001549         -0.002662       1.000000
# fr_ma_rech30                   0.001158          0.002876       0.001669
# sumamnt_ma_rech30              0.000046          0.440821       0.656986
# medianamnt_ma_rech30           0.001037          0.794646      -0.011792
# medianmarechprebal30           0.002849         -0.002342       0.000082
# cnt_ma_rech90                  0.001272          0.016707       0.886433
# fr_ma_rech90                   0.000798          0.106267      -0.152759
# sumamnt_ma_rech90             -0.000414          0.418735       0.584060
# medianamnt_ma_rech90           0.000219          0.818734      -0.051347
# medianmarechprebal90           0.004158          0.124646       0.013463
# cnt_da_rech30                 -0.003628         -0.001837       0.002306
# fr_da_rech30                  -0.000074         -0.003230      -0.002732
# cnt_da_rech90                 -0.001859          0.014779       0.011981
# fr_da_rech90                  -0.000203          0.016042       0.006989
# cnt_loans30                    0.000380         -0.027612       0.765802
# amnt_loans30                   0.000536          0.008502       0.752296
# maxamnt_loans30                0.000503          0.001000       0.000109
# medianamnt_loans30             0.000061          0.028370      -0.067011
# cnt_loans90                   -0.000972          0.000093       0.014703
# amnt_loans90                   0.000519          0.014067       0.685257
# maxamnt_loans90                0.001524          0.148460       0.174104
# medianamnt_loans90            -0.002239          0.021004      -0.071451
# payback30                      0.000077         -0.027369       0.043617
# payback90                      0.000417         -0.014260       0.017362
#
#                       fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# Unnamed: 0                0.003181           0.000123             -0.001371
# label                     0.001330           0.202828              0.141490
# aon                      -0.001163           0.000707              0.004306
# daily_decr30             -0.000577           0.636536              0.295356
# daily_decr90             -0.000343           0.603886              0.282960
# rental30                 -0.001219           0.272649              0.129853
# rental90                 -0.000503           0.259709              0.120242
# last_rech_date_ma        -0.001629           0.002105             -0.001358
# last_rech_date_da         0.001158           0.000046              0.001037
# last_rech_amt_ma          0.002876           0.440821              0.794646
# cnt_ma_rech30             0.001669           0.656986             -0.011792
# fr_ma_rech30              1.000000           0.000714             -0.000579
# sumamnt_ma_rech30         0.000714           1.000000              0.489200
# medianamnt_ma_rech30     -0.000579           0.489200              1.000000
# medianmarechprebal30      0.002613           0.000007             -0.000737
# cnt_ma_rech90             0.001220           0.596478              0.005309
# fr_ma_rech90             -0.001245          -0.071089              0.149655
# sumamnt_ma_rech90        -0.000571           0.889989              0.449012
# medianamnt_ma_rech90     -0.001573           0.422009              0.864846
# medianmarechprebal90     -0.002826           0.090502              0.156028
# cnt_da_rech30            -0.000511           0.002537             -0.000060
# fr_da_rech30             -0.001715          -0.001578             -0.001479
# cnt_da_rech90             0.001574           0.019213              0.016727
# fr_da_rech90             -0.001925           0.017255              0.013734
# cnt_loans30               0.002666           0.491864             -0.029789
# amnt_loans30              0.002470           0.531079              0.007125
# maxamnt_loans30          -0.001100           0.001633              0.001985
# medianamnt_loans30       -0.000331          -0.034460              0.032477
# cnt_loans90               0.003368           0.009419             -0.001143
# amnt_loans90              0.002634           0.484761              0.014546
# maxamnt_loans90          -0.001890           0.257705              0.159613
# medianamnt_loans90       -0.001292          -0.042244              0.022692
# payback30                 0.001455           0.000112             -0.018398
# payback90                 0.000998          -0.012596             -0.002861
#
#                       medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  \
# Unnamed: 0                        0.001258       0.002329     -0.000249
# label                            -0.004829       0.236392      0.084385
# aon                               0.003930      -0.002725      0.004401
# daily_decr30                     -0.001153       0.587338     -0.078299
# daily_decr90                     -0.000746       0.593069     -0.079530
# rental30                         -0.001415       0.312118     -0.033530
# rental90                         -0.001237       0.345293     -0.036524
# last_rech_date_ma                 0.004071       0.004263      0.001414
# last_rech_date_da                 0.002849       0.001272      0.000798
# last_rech_amt_ma                 -0.002342       0.016707      0.106267
# cnt_ma_rech30                     0.000082       0.886433     -0.152759
# fr_ma_rech30                      0.002613       0.001220     -0.001245
# sumamnt_ma_rech30                 0.000007       0.596478     -0.071089
# medianamnt_ma_rech30             -0.000737       0.005309      0.149655
# medianmarechprebal30              1.000000       0.000899     -0.000902
# cnt_ma_rech90                     0.000899       1.000000     -0.149068
# fr_ma_rech90                     -0.000902      -0.149068      1.000000
# sumamnt_ma_rech90                -0.000665       0.687054     -0.065566
# medianamnt_ma_rech90             -0.001459      -0.035497      0.138503
# medianmarechprebal90              0.000529       0.015461      0.004347
# cnt_da_rech30                    -0.003404       0.002895      0.002230
# fr_da_rech30                      0.000742      -0.002795     -0.000081
# cnt_da_rech90                    -0.003064       0.004090     -0.006727
# fr_da_rech90                     -0.001412       0.002865     -0.003822
# cnt_loans30                      -0.000211       0.689002     -0.119083
# amnt_loans30                      0.000134       0.707558     -0.123664
# maxamnt_loans30                  -0.002176      -0.000573      0.001635
# medianamnt_loans30               -0.002289      -0.053637      0.020626
# cnt_loans90                       0.001342       0.015754     -0.002756
# amnt_loans90                      0.000736       0.783419     -0.132035
# maxamnt_loans90                  -0.002141       0.244602     -0.045780
# medianamnt_loans90               -0.001927      -0.072481      0.016964
# payback30                         0.001516       0.011943      0.036817
# payback90                         0.001811      -0.003141      0.077529
#
#                       sumamnt_ma_rech90  medianamnt_ma_rech90  \
# Unnamed: 0                     0.000523             -0.000298
# label                          0.205793              0.120855
# aon                            0.001011              0.004909
# daily_decr30                   0.762981              0.257847
# daily_decr90                   0.768817              0.250518
# rental30                       0.342306              0.110356
# rental90                       0.360601              0.103151
# last_rech_date_ma              0.002243             -0.000726
# last_rech_date_da             -0.000414              0.000219
# last_rech_amt_ma               0.418735              0.818734
# cnt_ma_rech30                  0.584060             -0.051347
# fr_ma_rech30                  -0.000571             -0.001573
# sumamnt_ma_rech30              0.889989              0.422009
# medianamnt_ma_rech30           0.449012              0.864846
# medianmarechprebal30          -0.000665             -0.001459
# cnt_ma_rech90                  0.687054             -0.035497
# fr_ma_rech90                  -0.065566              0.138503
# sumamnt_ma_rech90              1.000000              0.429274
# medianamnt_ma_rech90           0.429274              1.000000
# medianmarechprebal90           0.096385              0.209096
# cnt_da_rech30                  0.003002             -0.002425
# fr_da_rech30                  -0.001566             -0.002289
# cnt_da_rech90                  0.012465              0.017533
# fr_da_rech90                   0.013136              0.019677
# cnt_loans30                    0.442766             -0.060766
# amnt_loans30                   0.508599             -0.025307
# maxamnt_loans30                0.001152              0.001016
# medianamnt_loans30            -0.022133              0.036475
# cnt_loans90                    0.011306             -0.000123
# amnt_loans90                   0.562609             -0.023450
# maxamnt_loans90                0.321739              0.134139
# medianamnt_loans90            -0.042386              0.031696
# payback30                     -0.026409             -0.035640
# payback90                     -0.029997             -0.023022
#
#                       medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# Unnamed: 0                       -0.001947       0.000888     -0.002504
# label                             0.039300       0.003827     -0.000027
# aon                              -0.000859       0.001564      0.000892
# daily_decr30                      0.037495       0.000700     -0.001499
# daily_decr90                      0.036382       0.000661     -0.001570
# rental30                          0.027170      -0.001105     -0.002558
# rental90                          0.029547      -0.000548     -0.002345
# last_rech_date_ma                -0.001086      -0.003467     -0.003626
# last_rech_date_da                 0.004158      -0.003628     -0.000074
# last_rech_amt_ma                  0.124646      -0.001837     -0.003230
# cnt_ma_rech30                     0.013463       0.002306     -0.002732
# fr_ma_rech30                     -0.002826      -0.000511     -0.001715
# sumamnt_ma_rech30                 0.090502       0.002537     -0.001578
# medianamnt_ma_rech30              0.156028      -0.000060     -0.001479
# medianmarechprebal30              0.000529      -0.003404      0.000742
# cnt_ma_rech90                     0.015461       0.002895     -0.002795
# fr_ma_rech90                      0.004347       0.002230     -0.000081
# sumamnt_ma_rech90                 0.096385       0.003002     -0.001566
# medianamnt_ma_rech90              0.209096      -0.002425     -0.002289
# medianmarechprebal90              1.000000       0.001130     -0.001893
# cnt_da_rech30                     0.001130       1.000000      0.005203
# fr_da_rech30                     -0.001893       0.005203      1.000000
# cnt_da_rech90                     0.007077       0.002153      0.000770
# fr_da_rech90                      0.008492       0.000088      0.005505
# cnt_loans30                      -0.043381       0.001852     -0.003212
# amnt_loans30                     -0.033878       0.001487     -0.003395
# maxamnt_loans30                   0.001884      -0.000394     -0.001070
# medianamnt_loans30                0.030534       0.000049     -0.001141
# cnt_loans90                      -0.000926      -0.001986     -0.001623
# amnt_loans90                     -0.036412       0.003369     -0.001593
# maxamnt_loans90                   0.027130      -0.000647     -0.001069
# medianamnt_loans90                0.032453      -0.001365     -0.001623
# payback30                        -0.031760      -0.000471      0.001709
# payback90                        -0.031210       0.000382     -0.000725
#
#                       cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# Unnamed: 0                -0.001324     -0.002827     0.001725      0.002387
# label                      0.002999     -0.005418     0.196283      0.197272
# aon                        0.001121      0.005395    -0.001826     -0.001726
# daily_decr30               0.038814      0.020673     0.366116      0.471492
# daily_decr90               0.031155      0.016437     0.340387      0.447869
# rental30                   0.072255      0.046761     0.180203      0.233453
# rental90                   0.056282      0.036886     0.171595      0.231906
# last_rech_date_ma         -0.003538     -0.002395     0.001193      0.000903
# last_rech_date_da         -0.001859     -0.000203     0.000380      0.000536
# last_rech_amt_ma           0.014779      0.016042    -0.027612      0.008502
# cnt_ma_rech30              0.011981      0.006989     0.765802      0.752296
# fr_ma_rech30               0.001574     -0.001925     0.002666      0.002470
# sumamnt_ma_rech30          0.019213      0.017255     0.491864      0.531079
# medianamnt_ma_rech30       0.016727      0.013734    -0.029789      0.007125
# medianmarechprebal30      -0.003064     -0.001412    -0.000211      0.000134
# cnt_ma_rech90              0.004090      0.002865     0.689002      0.707558
# fr_ma_rech90              -0.006727     -0.003822    -0.119083     -0.123664
# sumamnt_ma_rech90          0.012465      0.013136     0.442766      0.508599
# medianamnt_ma_rech90       0.017533      0.019677    -0.060766     -0.025307
# medianmarechprebal90       0.007077      0.008492    -0.043381     -0.033878
# cnt_da_rech30              0.002153      0.000088     0.001852      0.001487
# fr_da_rech30               0.000770      0.005505    -0.003212     -0.003395
# cnt_da_rech90              1.000000      0.348885     0.017976      0.026249
# fr_da_rech90               0.348885      1.000000     0.010021      0.014935
# cnt_loans30                0.017976      0.010021     1.000000      0.957742
# amnt_loans30               0.026249      0.014935     0.957742      1.000000
# maxamnt_loans30           -0.001855     -0.000754     0.000251     -0.000073
# medianamnt_loans30        -0.003351     -0.002234    -0.093146     -0.078531
# cnt_loans90                0.000907      0.001993     0.015595      0.014625
# amnt_loans90               0.020909      0.011501     0.852905      0.897961
# maxamnt_loans90            0.038019      0.021785     0.143590      0.329170
# medianamnt_loans90        -0.003094     -0.000949    -0.097871     -0.087989
# payback30                  0.013430      0.000354     0.067842      0.060425
# payback90                  0.024046      0.001226     0.033369      0.030901
#
#                       maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# Unnamed: 0                   0.000698           -0.002005     0.002241
# label                        0.000248            0.044589     0.004733
# aon                         -0.002764            0.004664    -0.000611
# daily_decr30                -0.000028           -0.011610     0.008962
# daily_decr90                 0.000025           -0.005591     0.009446
# rental30                    -0.000864           -0.016482     0.004012
# rental90                    -0.001411           -0.009467     0.005141
# last_rech_date_ma            0.000928            0.001835    -0.000225
# last_rech_date_da            0.000503            0.000061    -0.000972
# last_rech_amt_ma             0.001000            0.028370     0.000093
# cnt_ma_rech30                0.000109           -0.067011     0.014703
# fr_ma_rech30                -0.001100           -0.000331     0.003368
# sumamnt_ma_rech30            0.001633           -0.034460     0.009419
# medianamnt_ma_rech30         0.001985            0.032477    -0.001143
# medianmarechprebal30        -0.002176           -0.002289     0.001342
# cnt_ma_rech90               -0.000573           -0.053637     0.015754
# fr_ma_rech90                 0.001635            0.020626    -0.002756
# sumamnt_ma_rech90            0.001152           -0.022133     0.011306
# medianamnt_ma_rech90         0.001016            0.036475    -0.000123
# medianmarechprebal90         0.001884            0.030534    -0.000926
# cnt_da_rech30               -0.000394            0.000049    -0.001986
# fr_da_rech30                -0.001070           -0.001141    -0.001623
# cnt_da_rech90               -0.001855           -0.003351     0.000907
# fr_da_rech90                -0.000754           -0.002234     0.001993
# cnt_loans30                  0.000251           -0.093146     0.015595
# amnt_loans30                -0.000073           -0.078531     0.014625
# maxamnt_loans30              1.000000            0.007782     0.003987
# medianamnt_loans30           0.007782            1.000000    -0.003670
# cnt_loans90                  0.003987           -0.003670     1.000000
# amnt_loans90                -0.001850           -0.067580     0.017697
# maxamnt_loans90             -0.000487            0.058378     0.001450
# medianamnt_loans90           0.009330            0.911604    -0.002571
# payback30                   -0.001512           -0.006007     0.000587
# payback90                   -0.000915            0.003178    -0.000476
#
#                       amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# Unnamed: 0                0.000781         0.001742           -0.002615
# label                     0.199788         0.084144            0.035747
# aon                      -0.002319        -0.001191            0.002771
# daily_decr30              0.563496         0.400199           -0.037305
# daily_decr90              0.567204         0.397251           -0.034686
# rental30                  0.298943         0.234211           -0.035489
# rental90                  0.327436         0.251029           -0.034122
# last_rech_date_ma         0.000870        -0.001123            0.002771
# last_rech_date_da         0.000519         0.001524           -0.002239
# last_rech_amt_ma          0.014067         0.148460            0.021004
# cnt_ma_rech30             0.685257         0.174104           -0.071451
# fr_ma_rech30              0.002634        -0.001890           -0.001292
# sumamnt_ma_rech30         0.484761         0.257705           -0.042244
# medianamnt_ma_rech30      0.014546         0.159613            0.022692
# medianmarechprebal30      0.000736        -0.002141           -0.001927
# cnt_ma_rech90             0.783419         0.244602           -0.072481
# fr_ma_rech90             -0.132035        -0.045780            0.016964
# sumamnt_ma_rech90         0.562609         0.321739           -0.042386
# medianamnt_ma_rech90     -0.023450         0.134139            0.031696
# medianmarechprebal90     -0.036412         0.027130            0.032453
# cnt_da_rech30             0.003369        -0.000647           -0.001365
# fr_da_rech30             -0.001593        -0.001069           -0.001623
# cnt_da_rech90             0.020909         0.038019           -0.003094
# fr_da_rech90              0.011501         0.021785           -0.000949
# cnt_loans30               0.852905         0.143590           -0.097871
# amnt_loans30              0.897961         0.329170           -0.087989
# maxamnt_loans30          -0.001850        -0.000487            0.009330
# medianamnt_loans30       -0.067580         0.058378            0.911604
# cnt_loans90               0.017697         0.001450           -0.002571
# amnt_loans90              1.000000         0.323417           -0.095160
# maxamnt_loans90           0.323417         1.000000            0.032256
# medianamnt_loans90       -0.095160         0.032256            1.000000
# payback30                 0.052142         0.013376           -0.013388
# payback90                 0.029653         0.029679           -0.010443
#
#                       payback30  payback90
# Unnamed: 0            -0.000040   0.002411
# label                  0.048336   0.049183
# aon                    0.001940   0.002203
# daily_decr30           0.026915   0.047175
# daily_decr90           0.019400   0.040800
# rental30               0.072974   0.095147
# rental90               0.067110   0.099501
# last_rech_date_ma     -0.002233  -0.001583
# last_rech_date_da      0.000077   0.000417
# last_rech_amt_ma      -0.027369  -0.014260
# cnt_ma_rech30          0.043617   0.017362
# fr_ma_rech30           0.001455   0.000998
# sumamnt_ma_rech30      0.000112  -0.012596
# medianamnt_ma_rech30  -0.018398  -0.002861
# medianmarechprebal30   0.001516   0.001811
# cnt_ma_rech90          0.011943  -0.003141
# fr_ma_rech90           0.036817   0.077529
# sumamnt_ma_rech90     -0.026409  -0.029997
# medianamnt_ma_rech90  -0.035640  -0.023022
# medianmarechprebal90  -0.031760  -0.031210
# cnt_da_rech30         -0.000471   0.000382
# fr_da_rech30           0.001709  -0.000725
# cnt_da_rech90          0.013430   0.024046
# fr_da_rech90           0.000354   0.001226
# cnt_loans30            0.067842   0.033369
# amnt_loans30           0.060425   0.030901
# maxamnt_loans30       -0.001512  -0.000915
# medianamnt_loans30    -0.006007   0.003178
# cnt_loans90            0.000587  -0.000476
# amnt_loans90           0.052142   0.029653
# maxamnt_loans90        0.013376   0.029679
# medianamnt_loans90    -0.013388  -0.010443
# payback30              1.000000   0.830363
# payback90              0.830363   1.000000

# %% [markdown]
# In this above correlation table we can say that there are many features correlation with target is negligible. But we can not drop those columns based on one evidence, so we will do some analysis and try to proof that is there really no relation with target or not.?

# %%
#checkig NaNs
df.isna().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %% [markdown]
# As we assume that there is no Null values present in the dataset.

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is not any duplicates present.

# %% [markdown]
# ### Dropping Non-required features

# %% [markdown]
# - Unnamed: 0 feature is kind of serial number and we also check the correlation with target of this feature and we conclude that we will drop this features as it is not related with target.
# - msisdn feature is a mobile number of the customers. Ovioulsly we know that how can a mobile number is related with target, that the customer will pay the credit amount or not.

# %%
df=df.drop(columns=["Unnamed: 0","msisdn"])
print("New shape  of the dataset is  : ", df.shape)
# Out:
# New shape  of the dataset is  :  (209593, 35)

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %% [markdown]
# ### Checking Imbalancing dataset:

# %%
print(df.label.value_counts())
print('\n')
plt.figure(figsize=(7,10))
plt.subplot(2,1,1)
sns.countplot(df.label)
plt.tight_layout

plt.subplot(2,1,2)
df.label.value_counts().plot.pie(autopct='%1.1f%%')
plt.tight_layout()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# - We can see the imbalanced dataset here.
# - As we can from above graph 87.5% customers are payed it's credit card payment but 12.5% customers are not payed.
# - So that we can say that we have biased class, which is the distinctive example of Imbalanced Classification Problem. We will use Over-Sampling or Under-Sampling technique to handle this type of problem. We will take care of it before model building.

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# 1                    20.0                0.0              5787              1
# 2                     3.0                0.0              1539              1
# 3                    41.0                0.0               947              0
# 4                     4.0                0.0              2309              7
# ...                   ...                ...               ...            ...
# 209588                1.0                0.0              4048              3
# 209589                4.0                0.0               773              4
# 209590                3.0                0.0              1539              5
# 209591                2.0               38.0               773              5
# 209592               13.0                0.0              7526              2
#
#         fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0               21.0             3078.0                1539.0
# 1                0.0             5787.0                5787.0
# 2                0.0             1539.0                1539.0
# 3                0.0                0.0                   0.0
# 4                2.0            20029.0                2309.0
# ...              ...                ...                   ...
# 209588           2.0            10404.0                3178.0
# 209589           1.0             3092.0                 773.0
# 209590           8.0             9334.0                1539.0
# 209591           4.0            12154.0                 773.0
# 209592           1.0             9065.0                4532.5
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                       7.50              2            21               3078
# 1                      61.04              1             0               5787
# 2                      66.32              1             0               1539
# 3                       0.00              1             0                947
# 4                      29.00              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                 91.81              3             2              10404
# 209589                161.30              6             2               4038
# 209590                 51.13             11             5              18592
# 209591                164.00              6             4              17941
# 209592                356.70              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 0                     1539.0                  7.50            0.0
# 1                     5787.0                 61.04            0.0
# 2                     1539.0                 66.32            0.0
# 3                      947.0                  2.50            0.0
# 4                     2888.0                 35.00            0.0
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81            0.0
# 209589                 773.0                111.80            0.0
# 209590                1539.0                 47.13            0.0
# 209591                2410.5                100.00            0.0
# 209592                7526.0                392.20            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 0                0.0              0             0            2            12
# 1                0.0              0             0            1            12
# 2                0.0              0             0            1             6
# 3                0.0              0             0            2            12
# 4                0.0              0             0            7            42
# ...              ...            ...           ...          ...           ...
# 209588           0.0              0             0            2            12
# 209589           0.0              0             0            3            18
# 209590           0.0              0             0            4            42
# 209591           0.0              1             0            2            18
# 209592           0.0              0             0            2            18
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle  \
# 0                     6                 0.0  29.000000  29.000000     UPW
# 1                    12                 0.0   0.000000   0.000000     UPW
# 2                     6                 0.0   0.000000   0.000000     UPW
# 3                     6                 0.0   0.000000   0.000000     UPW
# 4                     6                 0.0   2.333333   2.333333     UPW
# ...                 ...                 ...        ...        ...     ...
# 209588                6                 0.0   1.000000   1.000000     UPW
# 209589                6                 0.0   1.000000   1.000000     UPW
# 209590               12                 0.0   4.000000   3.833333     UPW
# 209591               12                 0.0   0.000000  10.500000     UPW
# 209592               12                 0.0   0.000000   0.000000     UPW
#
#              pdate
# 0       2016-07-20
# 1       2016-08-10
# 2       2016-08-19
# 3       2016-06-06
# 4       2016-06-22
# ...            ...
# 209588  2016-06-17
# 209589  2016-06-12
# 209590  2016-07-29
# 209591  2016-07-25
# 209592  2016-07-07
#
# [209593 rows x 35 columns]

# %%
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %% [markdown]
# 'pcircle' feature has only one unique value. So we can drop it that also.

# %%
df=df.drop('pcircle',axis=1)

# %% [markdown]
# #### Pdate

# %% [markdown]
# pdate feature hold the Date type data. So we will extract day month and year from it.

# %%
df["date"] = pd.to_datetime(df.pdate,format = "%Y-%m-%d").dt.day
df["month"] = pd.to_datetime(df.pdate,format = "%Y-%m-%d").dt.month
df["year"] = pd.to_datetime(df.pdate,format = "%Y-%m-%d").dt.year

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# 1                    20.0                0.0              5787              1
# 2                     3.0                0.0              1539              1
# 3                    41.0                0.0               947              0
# 4                     4.0                0.0              2309              7
# ...                   ...                ...               ...            ...
# 209588                1.0                0.0              4048              3
# 209589                4.0                0.0               773              4
# 209590                3.0                0.0              1539              5
# 209591                2.0               38.0               773              5
# 209592               13.0                0.0              7526              2
#
#         fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0               21.0             3078.0                1539.0
# 1                0.0             5787.0                5787.0
# 2                0.0             1539.0                1539.0
# 3                0.0                0.0                   0.0
# 4                2.0            20029.0                2309.0
# ...              ...                ...                   ...
# 209588           2.0            10404.0                3178.0
# 209589           1.0             3092.0                 773.0
# 209590           8.0             9334.0                1539.0
# 209591           4.0            12154.0                 773.0
# 209592           1.0             9065.0                4532.5
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                       7.50              2            21               3078
# 1                      61.04              1             0               5787
# 2                      66.32              1             0               1539
# 3                       0.00              1             0                947
# 4                      29.00              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                 91.81              3             2              10404
# 209589                161.30              6             2               4038
# 209590                 51.13             11             5              18592
# 209591                164.00              6             4              17941
# 209592                356.70              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 0                     1539.0                  7.50            0.0
# 1                     5787.0                 61.04            0.0
# 2                     1539.0                 66.32            0.0
# 3                      947.0                  2.50            0.0
# 4                     2888.0                 35.00            0.0
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81            0.0
# 209589                 773.0                111.80            0.0
# 209590                1539.0                 47.13            0.0
# 209591                2410.5                100.00            0.0
# 209592                7526.0                392.20            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 0                0.0              0             0            2            12
# 1                0.0              0             0            1            12
# 2                0.0              0             0            1             6
# 3                0.0              0             0            2            12
# 4                0.0              0             0            7            42
# ...              ...            ...           ...          ...           ...
# 209588           0.0              0             0            2            12
# 209589           0.0              0             0            3            18
# 209590           0.0              0             0            4            42
# 209591           0.0              1             0            2            18
# 209592           0.0              0             0            2            18
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90       pdate  \
# 0                     6                 0.0  29.000000  29.000000  2016-07-20
# 1                    12                 0.0   0.000000   0.000000  2016-08-10
# 2                     6                 0.0   0.000000   0.000000  2016-08-19
# 3                     6                 0.0   0.000000   0.000000  2016-06-06
# 4                     6                 0.0   2.333333   2.333333  2016-06-22
# ...                 ...                 ...        ...        ...         ...
# 209588                6                 0.0   1.000000   1.000000  2016-06-17
# 209589                6                 0.0   1.000000   1.000000  2016-06-12
# 209590               12                 0.0   4.000000   3.833333  2016-07-29
# 209591               12                 0.0   0.000000  10.500000  2016-07-25
# 209592               12                 0.0   0.000000   0.000000  2016-07-07
#
#         date  month  year
# 0         20      7  2016
# 1         10      8  2016
# 2         19      8  2016
# 3          6      6  2016
# 4         22      6  2016
# ...      ...    ...   ...
# 209588    17      6  2016
# 209589    12      6  2016
# 209590    29      7  2016
# 209591    25      7  2016
# 209592     7      7  2016
#
# [209593 rows x 37 columns]

# %%
# checking year's values
df.year.value_counts()
# Out:
# 2016    209593
# Name: year, dtype: int64

# %% [markdown]
# As we can see that there is only one unique value present in year feature.So We will drop it as well.

# %%
df=df.drop(columns=['pdate','year'])

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90  date  month
# 0                 0.0  29.000000  29.000000    20      7
# 1                 0.0   0.000000   0.000000    10      8
# 2                 0.0   0.000000   0.000000    19      8
# 3                 0.0   0.000000   0.000000     6      6
# 4                 0.0   2.333333   2.333333    22      6

# %% [markdown]
# ### Checking the relation with target variable

# %%
def RelationWithTarget(feature):
    
    plt.figure(figsize=(12,10))
    plt.subplot(2,1,1)
    ax=sns.kdeplot(df[feature][df['label']==1],color='red',shade=True)
    sns.kdeplot(df[feature][df['label']==0],ax=ax,color='blue',shade=True)
    ax.legend(['Paid','NotPaid'],loc='upper right')
    plt.tight_layout()
    
    plt.subplot(2,1,2)
    sns.stripplot(x = df['label'],y =df[feature])
    plt.tight_layout()

# %% [markdown]
# #### age on cellular network in days (aon)

# %%
RelationWithTarget('aon')

# %% [markdown]
# - As we can see in the first figure that most of the data points fall betweeen 0 to 0.05 le^6.
# - As less number of age on cellular network(in days), as higher chance of user paid back the credit amount.
# - We can not differentiate with paid or non paid graph so we can say that there is negligible relation or no relation between feature and target.

# %% [markdown]
# #### daily_decr30 :- Daily amount spent from main account, (averaged over last 30 days)

# %%
RelationWithTarget('daily_decr30')

# %% [markdown]
# - Daily amount spent from main account when its 0, there is high chance the user did not paid, but as daily amount spent from main account increases the user paid back the credit amount.

# %% [markdown]
# #### daily_decr90:- Daily amount spent from main account (averaged over last 90 days)

# %%
RelationWithTarget('daily_decr90')

# %% [markdown]
# - As we have seen previously that as Daily amount of user's main account is increases than it's high probability that user paid back it's credit amount.

# %% [markdown]
# #### rental30:-Average main account balance (last 30 days)

# %%
RelationWithTarget('rental30')

# %% [markdown]
# - Most of the users did not maintain it's account. Their account balance is zero that's why they fraud with the company.
# - As we seen that as Avg main balance is increasing the chance is also increasing that user paid back to us.

# %% [markdown]
# #### rental90: Average main account balance (last 90 days)

# %%
RelationWithTarget('rental90')

# %% [markdown]
# Same applies here also.

# %% [markdown]
# #### last_rech_date_ma:- Number of days till last recharge of main account

# %%
RelationWithTarget('last_rech_date_ma')

# %% [markdown]
# - most of the data point fall inaround 0 but.
# - Here we can not differentiate between paid back user and non paid user. So we can say there is no relation between feature and label.

# %% [markdown]
# #### last_rech_date_da:- Number of days till last recharge of data account

# %%
RelationWithTarget('last_rech_date_da')

# %% [markdown]
# - We can not compare this feature with paid label and non paid label. So we can say that there is no relation between last_rech-date_da with label.

# %% [markdown]
# #### last_rech_amt_ma:- Amount of last recharge of main account

# %%
RelationWithTarget('last_rech_amt_ma')

# %% [markdown]
# - We can easily see that When last recharge is zero, then the fraud chance is very high, but as the amount of recharge is increasing the fraud chance decreasing drastically. It mean we can say that as recharge amount increasing the possibility also increasing that user paid back its credit amount.

# %% [markdown]
# #### cnt_ma_rech30 :- Number of times main account got recharged (last 30 days)

# %%
RelationWithTarget('cnt_ma_rech30')

# %% [markdown]
# - As we can see that in the above graphs, When number of recharge in main account is zero than the fraud chance is very high, but as number of recharge in main account increases the fraud chance is drastically decreasing.
# - If number of recharge is greater then 50, that time user 100% pay back its credit amount.

# %% [markdown]
# #### fr_ma_rech90:- Frequency of main account recharged (last 90 days)

# %%
RelationWithTarget('fr_ma_rech90')

# %% [markdown]
# - When frequency, when main account got recharged, is zero or around zero that time fraud chance is very high,.
# - As frequency, when main account got recharge, is increasing that time 50-50% chance that user pay back it's credit amount or not.
# - When frequency is between 30 to 40, we can see the little bump in the graph 1, it mean this time the probability is high that the user will pay back.

# %% [markdown]
# #### sumamnt_ma_rech90:- Total amount of recharge in main account (last 90days)

# %%
RelationWithTarget('sumamnt_ma_rech90')

# %% [markdown]
# - When sum of total amount of recharge is around zero, fraud probality is high ,but as recharge amount is increases the fraud chance go down and down.

# %% [markdown]
# #### medianamnt_ma_rech90:- Median of amount of recharges done in main account

# %%
RelationWithTarget('medianamnt_ma_rech90')

# %% [markdown]
# #### medianmarechprebal90:- Median of main account balance just before recharge

# %%
RelationWithTarget('medianmarechprebal90')

# %% [markdown]
# - The relationship of this feature with target is very low or we can say no relation.

# %% [markdown]
# #### cnt_da_rech30:- Number of times data account got recharged (last 30 days)

# %%
RelationWithTarget('cnt_da_rech30')

# %% [markdown]
# - Here we see that we can not differentiate between fraud or not fraud. It mean that there is no relation with target and this feature.

# %% [markdown]
# #### fr_da_rech30:- Frequency of data account recharged (last 30 days)

# %%
RelationWithTarget('fr_da_rech30')

# %% [markdown]
# There is no relation between target and feature.

# %% [markdown]
# #### cnt_da_rech90:- Number of times data account got recharged (last 90 days)

# %%
RelationWithTarget('cnt_da_rech90')

# %% [markdown]
# - At the begging we observe that there is 50-50% chance that user pay back or not based on number of times data account got recharged.
# - when data account got recharged 30 times or more then 30 times, than there is 100% chance that user pay back it's credit amount.

# %% [markdown]
# #### fr_da_rech90:- Frequency of data account recharged (last 90 days)

# %%
RelationWithTarget('fr_da_rech90')

# %% [markdown]
# - if the frequency of number, when data account got recharged, has gone above 35 then there is no chance that user found cheated.

# %% [markdown]
# #### cnt_loans30:- Number of loans taken by user (last 30 days)

# %%
RelationWithTarget('cnt_loans30')

# %% [markdown]
# - It interesting that when user did not take any loan, that time they cheat with company.
# - If user take loan more than 5 times there is less chance that user will cheat with company.

# %% [markdown]
# #### amnt_loans30:- Total amount of loans taken by user (last 30 days)

# %%
RelationWithTarget('amnt_loans30')

# %% [markdown]
# - as loan amount increasing the chance of cheating is decreasing.
# - if Loan amount is gone upto 150 than there is no chance that user cheated with company.

# %% [markdown]
# #### maxamnt_loans30:- maximum amount of loan taken by the user (last 30 days)

# %%
RelationWithTarget('maxamnt_loans30')

# %% [markdown]
# - We observe from the above graph that we can not find that user will cheat us or not based on maximum loan amount which taken by user.
# - It mean there is no relation of this feature with target.

# %% [markdown]
# #### medianamnt_loans30:- Median of amounts of loan taken by the user (last 30 days)

# %%
RelationWithTarget('medianamnt_loans30')

# %% [markdown]
# - If Median of amounts of loan taken by the user is above 1 than there is 100% chance that user will pay back to the company.

# %% [markdown]
# #### cnt_loans90:- Number of loans taken by user (last 90 days)

# %%
RelationWithTarget('cnt_loans90')

# %% [markdown]
# - There is no relation with Number of loans taken by user with target.

# %% [markdown]
# #### amnt_loans90:- Total amount of loans taken by user (last 90 days)

# %%
RelationWithTarget('amnt_loans90')

# %% [markdown]
# - We can see clear up-trend here. As loan amount increasing than chances of scam is getting down.
# - And if the loan amount is above 200 then scam chances is become 0%.

# %% [markdown]
# #### maxamnt_loans90: maximum amount of loan taken by the user (last 90 days)

# %%
RelationWithTarget('maxamnt_loans90')

# %% [markdown]
# - If loan amount of user is low or below 5 unit, then user pay back to the company 100%.
# - but as loan amount increasing above 5 unit, then fraud chance also increases.

# %% [markdown]
# #### medianamnt_loans90:- Median of amounts of loan taken by the user (last 90 days)

# %%
RelationWithTarget('medianamnt_loans90')

# %% [markdown]
# #### payback30:- Average payback time in days over (last 30 days)

# %%
RelationWithTarget('payback30')

# %% [markdown]
# - There is very less relation between payback30 feature with target.
# - both graph showing parallel relation with target.

# %% [markdown]
# #### payback90:- Average payback time in days (last 90 days)

# %%
RelationWithTarget('payback90')

# %% [markdown]
# #### DATE

# %%
RelationWithTarget('date')

# %% [markdown]
# - There is no realtion between date or label.

# %% [markdown]
# #### Month

# %%
RelationWithTarget('month')

# %% [markdown]
# - In month 8(august) 100% user back pay to the company.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# based on above analysis(Relationship With Target) we find that some features did not add any value for predicting the label. So we will drop those all features. Those features are listed below:-
#
# - aon
# - last_rech_date_ma
# - last_rech_date_da
# - fr_ma_rech90
# - cnt_da_rech30
# - fr_da_rech30
# - maxamnt_loans30
# - cnt_loans90
# - payback30
# - date
# - payback90

# %%
df=df.drop(columns=['aon','last_rech_date_ma','last_rech_date_da','fr_ma_rech90',
                   'cnt_da_rech30','fr_da_rech30','maxamnt_loans30','cnt_loans90','payback30','date','payback90'])

# %%
print(df.shape)
df.head()
# Out:
# (209593, 24)
#    label  daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0      0   3055.050000   3065.150000    220.13    260.13              1539
# 1      1  12122.000000  12124.750000   3691.26   3691.26              5787
# 2      1   1398.000000   1398.000000    900.13    900.13              1539
# 3      1     21.228000     21.228000    159.42    159.42               947
# 4      1    150.619333    150.619333   1098.90   1098.90              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2               3078
# 1                 61.04              1               5787
# 2                 66.32              1               1539
# 3                  0.00              1                947
# 4                 29.00              8              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech90  fr_da_rech90  \
# 0                1539.0                  7.50              0             0
# 1                5787.0                 61.04              0             0
# 2                1539.0                 66.32              0             0
# 3                 947.0                  2.50              0             0
# 4                2888.0                 35.00              0             0
#
#    cnt_loans30  amnt_loans30  medianamnt_loans30  amnt_loans90  \
# 0            2            12                 0.0            12
# 1            1            12                 0.0            12
# 2            1             6                 0.0             6
# 3            2            12                 0.0            12
# 4            7            42                 0.0            42
#
#    maxamnt_loans90  medianamnt_loans90  month
# 0                6                 0.0      7
# 1               12                 0.0      8
# 2                6                 0.0      8
# 3                6                 0.0      6
# 4                6                 0.0      6

# %% [markdown]
# Now we have only 24 columns left including target variable.

# %% [markdown]
# ### Checking The distribution

# %%
## creating a copy of data frame:
df1=df.copy()

# %%
### dropping  the label from copy dataframe:
df1.drop('label',axis=1,inplace=True)

# %%
## plotting graph from column number 1 to 8.
plt.figure(figsize=(15,15))
plotnumber=1
for column in df1.columns:
    if plotnumber<=8:
        plt.subplot(4,2,plotnumber)
        sns.distplot(x=df[column],color='purple',kde_kws={"color": "k", "lw": 2, "label": "KDE"})
        plt.xlabel(column,fontsize=25)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - daily_decr30,daily_decr90,last_rech_amt_ma,cnt_ma_rech30,fr_ma_rech30,sumamnt_ma_rech30 features are highly right skewed.
# - rental30,rental90 features are both right and left skewed.

# %%
## plotting graph from column number 9 to 16.
plt.figure(figsize=(15,15))
plotnumber=1
for column in df1.columns[8:16]:
    if plotnumber<=8 :
        plt.subplot(4,2,plotnumber)
        sns.distplot(x=df[column],color='purple',kde_kws={"color": "k", "lw": 2, "label": "KDE"})
        plt.xlabel(column,fontsize=25)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - All Features are highly right skewed. There may be outliers present in my data set we will check it in further steps.

# %%
## plotting graph from column number 17 to 24.
plt.figure(figsize=(15,15))
plotnumber=1
for column in df1.columns[16:24]:
    if plotnumber<=8 :
        plt.subplot(4,2,plotnumber)
        sns.distplot(x=df[column],color='purple',kde_kws={"color": "k", "lw": 2, "label": "KDE"})
        plt.xlabel(column,fontsize=25)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - we observe that almost all the features are highly right skewed or some are both right or left skewed. We have to handle this skewness otherwise our model become biased.
# - month, medianamnt_loans90,maxamnt_loans90,maxamnt_loans30 features having nomial data points, so we can not treat them in outliers checking.

# %% [markdown]
# ### Checking outliers

# %%
## plotting graph for checking outliers.
plt.figure(figsize=(13,40))
plotnumber=1
for column in df1.columns:
    if plotnumber<=30 :
        plt.subplot(13,2,plotnumber)
        sns.boxplot(x=df[column],color='purple',orient="h", palette="Set2")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - All the features having outliers present. We have to treat them accodingly.
# - as we already said that month, medianamnt_loans90,maxamnt_loans90,maxamnt_loans30 features having nomial data points, so we can not treat them in outliers checking.

# %% [markdown]
# ### Handling Outliers

# %% [markdown]
# As we all know data is pricious for us so we can not drop any data as it is. We have checked almost all the features having outlieres present. So we will not check outlier for nomial features. These features are listed below:-
#
# - cnt_da_rech90
# - fr_da_rech_90
# - medianamnt_loans30
# - maxamnt_loans90
# - medianamnt_loans90
# - month
# - cnt_loans30
# - fr_ma_rech30
# - cnt_ma_recch30
#
# In above graph we see that sumannt_ma_rech30,sumannt_ma_rech90,rental30,rental90,last_rech_amt_ma,cnt-da-rech90 features having outliers but all outliers are not not really far from maxium data point except one or two data points. so we can not treat outliers for them also.

# %%
df.columns
# Out:
# Index(['label', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'medianamnt_loans30', 'amnt_loans90', 'maxamnt_loans90',
#        'medianamnt_loans90', 'month'],
#       dtype='object')

# %%
outlier_feature=['daily_decr30', 'daily_decr90','medianamnt_ma_rech90',
       'medianmarechprebal90','amnt_loans30','amnt_loans90']
from scipy.stats import zscore
z_score=zscore(df[outlier_feature])
abs_z_score=np.abs(z_score)

# %%
removing_outlier=(abs_z_score<3).all(axis=1)
df_new=df[removing_outlier]
print('Pervious Shape:', df.shape)
print('After removing the new shape : ',df_new.shape)
# Out:
# Pervious Shape: (209593, 24)
# After removing the new shape :  (196637, 24)

# %% [markdown]
# ### Checking Data Loss

# %%
loss=(209593-196637)/209593*100
print('The Data Loss is : ', loss)
# Out:
# The Data Loss is :  6.181504153287562

# %% [markdown]
# Data loss is in under acceptable range. So we can go ahead.

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df_new.corr(),annot=True,annot_kws={'size':15},fmt='.2f',linewidth=0.4,linecolor='red')
plt.xticks(rotation=45,fontsize=15)

plt.yticks(rotation=45,fontsize=15)
plt.tight_layout()

# %% [markdown]
# - we see that fr_da_rech90 is negative correlated with the target.
# - daily_decr90 and daily_decr30 is highly 98% correlated with each other.
# - medianamnt_loans90 and medianamnt-loans30 is also highly correlated with 92% correlation.
# - amnt_loans30 and amnt_loans90 is also highly correlated with 88% correlation.
# - cnt_loans30 and amnt_loans90 also 84% correlated with each other.
# - cnt_loans30 is also 97% correlate with amnt-loans30.
# - rental90 is 96% correlate with rental30.
# - cnt_ma_rech90 is 87% correlated with cnt_ma-rech30.
# - medianamnt_ma_rech90 is 86% correlated with medianamnt-ma-rech30.
# - We can not drop these features based on one evidence. So we will check their relation with each other through graphs.
# - After confirming the relation with eachother we will drop one of feature between both of them who is less correlated with target variable.

# %% [markdown]
# ### Checking Multicollinearity

# %%
## defining a function:

def FeatureVsFeature(feature1,feature2):    
    plt.figure(figsize=(18,10))
    plt.subplot(2,1,2)
    sns.scatterplot(x=df_new[feature1],color='purple',y=df_new[feature2])
    plt.title('Relationshing using Scatter plot',fontsize=23)
    plt.ylabel(feature1,fontsize=15)
    plt.xlabel(feature2,fontsize=15)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.tight_layout()

# %% [markdown]
# #### daily_decr90 and daily_decr30

# %%
FeatureVsFeature('daily_decr90','daily_decr30')

# %% [markdown]
# - We can see the clear up trend here. Both features are tightly correlated with each other.

# %% [markdown]
# #### medianamnt_loans90 and medianamnt-loans30

# %%
FeatureVsFeature('medianamnt_loans90','medianamnt_loans30')

# %% [markdown]
# - We can not see that much of up or down trend here. So here we can say that no relation with feature vs feature.

# %% [markdown]
# #### amnt_loans30 and amnt_loans90

# %%
FeatureVsFeature('amnt_loans30','amnt_loans90')

# %% [markdown]
# - yes, here we can see the great up trend. So there is high correlation between these two features.

# %% [markdown]
# #### cnt_loans30 and amnt_loans90

# %%
FeatureVsFeature('cnt_loans30','amnt_loans90')

# %% [markdown]
# - So here we also see the high correlation between features.

# %% [markdown]
# #### cnt_loans30 & amnt-loans30

# %%
FeatureVsFeature('cnt_loans30','amnt_loans30')

# %% [markdown]
# - Yes...!! , Here we find the high relation between these two features.

# %% [markdown]
# #### cnt_ma_rech90 & cnt_ma-rech30

# %%
FeatureVsFeature('cnt_ma_rech90','cnt_ma_rech30')

# %% [markdown]
# #### Rental30 vs Rental90

# %%
FeatureVsFeature('rental30','rental90')

# %% [markdown]
# - here, we can see that the up-trend. It mean there is some relation between these features.

# %% [markdown]
# #### medianamnt_ma_rech90 &medianamnt-ma-rech30

# %%
FeatureVsFeature('medianamnt_ma_rech90','medianamnt_ma_rech30')

# %% [markdown]
# - But, here we see that there is No relation between these feature. We can not see any up trend here.

# %% [markdown]
# ### Conclusion of Multicollinearity

# %% [markdown]
# - daily_decr90 and daily_decr30 is highly correlated & both are 19% correlated with target so we will drop daily_decr30 here.
# - We did not find any relation between medianamnt_loans90 and medianamnt-loans30.
# - amnt_loans30 and amnt_loans90 is also highly correlated & both are 22% and 23% correlated with target respectvely.
# - cnt-loans30 is also correlated with amnt_loans90. so we will drop cnt-loans30 here
# - cnt_loans30 is also 97% correlate with amnt-loans30 so will drop cnt_loans 30 here.
# - rental90 is 96% correlate with rental30 & both are 0.06% and 0.05% related with target respectvely so we will drop rental30 here.
# - cnt_ma_rech90 is 87% correlated with cnt_ma-rech30 and both are 26% correlated with target so we will drop cnt_ma_rech30 here.
# - We did not find any relation between medianamnt_ma_rech90 with medianamnt-ma-rech30.

# %%
df_new=df_new.drop(columns=['daily_decr30','amnt_loans30','cnt_loans30','rental30','cnt_ma_rech30'])

# %%
print(df_new.shape)
df_new.head()
# Out:
# (196637, 19)
#    label  daily_decr90  rental90  last_rech_amt_ma  fr_ma_rech30  \
# 0      0   3065.150000    260.13              1539          21.0
# 1      1  12124.750000   3691.26              5787           0.0
# 2      1   1398.000000    900.13              1539           0.0
# 3      1     21.228000    159.42               947           0.0
# 4      1    150.619333   1098.90              2309           2.0
#
#    sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 0             3078.0                1539.0                  7.50
# 1             5787.0                5787.0                 61.04
# 2             1539.0                1539.0                 66.32
# 3                0.0                   0.0                  0.00
# 4            20029.0                2309.0                 29.00
#
#    cnt_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0              2               3078                1539.0
# 1              1               5787                5787.0
# 2              1               1539                1539.0
# 3              1                947                 947.0
# 4              8              23496                2888.0
#
#    medianmarechprebal90  cnt_da_rech90  fr_da_rech90  medianamnt_loans30  \
# 0                  7.50              0             0                 0.0
# 1                 61.04              0             0                 0.0
# 2                 66.32              0             0                 0.0
# 3                  2.50              0             0                 0.0
# 4                 35.00              0             0                 0.0
#
#    amnt_loans90  maxamnt_loans90  medianamnt_loans90  month
# 0            12                6                 0.0      7
# 1            12               12                 0.0      8
# 2             6                6                 0.0      8
# 3            12                6                 0.0      6
# 4            42                6                 0.0      6

# %% [markdown]
# ### Relation with Target

# %%
df_new.drop('label',axis=1).corrwith(df_new.label).plot(kind='bar',grid=True,figsize=(17,10),title='Correlation with target')
plt.tight_layout()

# %% [markdown]
# - cnt_ma_rech90 is high correlated with target.
# - fr_ma_rech30 is least correlated with target.

# %% [markdown]
# ### Checking skewness

# %%
df_new.skew()
# Out:
# label                   -2.186101
# daily_decr90             1.990263
# rental90                 4.380219
# last_rech_amt_ma         2.671435
# fr_ma_rech30            14.764050
# sumamnt_ma_rech30        2.875017
# medianamnt_ma_rech30     2.384533
# medianmarechprebal30    14.726477
# cnt_ma_rech90            2.081323
# sumamnt_ma_rech90        2.397616
# medianamnt_ma_rech90     2.276276
# medianmarechprebal90     3.623945
# cnt_da_rech90           27.928307
# fr_da_rech90            30.136185
# medianamnt_loans30       4.531760
# amnt_loans90             1.712200
# maxamnt_loans90          1.844849
# medianamnt_loans90       4.865652
# month                    0.395402
# dtype: float64

# %% [markdown]
# here we can see that all the features are highly skewed. We have to handle them accordingly.

# %%
df1=df_new.copy()

# %%
df_new.head()
# Out:
#    label  daily_decr90  rental90  last_rech_amt_ma  fr_ma_rech30  \
# 0      0   3065.150000    260.13              1539          21.0
# 1      1  12124.750000   3691.26              5787           0.0
# 2      1   1398.000000    900.13              1539           0.0
# 3      1     21.228000    159.42               947           0.0
# 4      1    150.619333   1098.90              2309           2.0
#
#    sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 0             3078.0                1539.0                  7.50
# 1             5787.0                5787.0                 61.04
# 2             1539.0                1539.0                 66.32
# 3                0.0                   0.0                  0.00
# 4            20029.0                2309.0                 29.00
#
#    cnt_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0              2               3078                1539.0
# 1              1               5787                5787.0
# 2              1               1539                1539.0
# 3              1                947                 947.0
# 4              8              23496                2888.0
#
#    medianmarechprebal90  cnt_da_rech90  fr_da_rech90  medianamnt_loans30  \
# 0                  7.50              0             0                 0.0
# 1                 61.04              0             0                 0.0
# 2                 66.32              0             0                 0.0
# 3                  2.50              0             0                 0.0
# 4                 35.00              0             0                 0.0
#
#    amnt_loans90  maxamnt_loans90  medianamnt_loans90  month
# 0            12                6                 0.0      7
# 1            12               12                 0.0      8
# 2             6                6                 0.0      8
# 3            12                6                 0.0      6
# 4            42                6                 0.0      6

# %%
df_new.columns
# Out:
# Index(['label', 'daily_decr90', 'rental90', 'last_rech_amt_ma', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech90', 'fr_da_rech90',
#        'medianamnt_loans30', 'amnt_loans90', 'maxamnt_loans90',
#        'medianamnt_loans90', 'month'],
#       dtype='object')

# %%
feature=['daily_decr90', 'rental90', 'last_rech_amt_ma', 'fr_ma_rech30',
       'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
       'cnt_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90', 'amnt_loans90']

for i in feature:
    df_new[i]=np.cbrt(df_new[i])
df_new.skew()
# Out:
# label                   -2.186101
# daily_decr90             0.442361
# rental90                 0.202705
# last_rech_amt_ma        -0.577155
# fr_ma_rech30            13.674708
# sumamnt_ma_rech30       -0.423210
# medianamnt_ma_rech30    -0.715236
# medianmarechprebal30    11.721843
# cnt_ma_rech90           -0.557688
# sumamnt_ma_rech90       -0.297338
# medianamnt_ma_rech90    -0.758152
# medianmarechprebal90    -0.264553
# cnt_da_rech90           27.928307
# fr_da_rech90            30.136185
# medianamnt_loans30       4.531760
# amnt_loans90             0.378695
# maxamnt_loans90          1.844849
# medianamnt_loans90       4.865652
# month                    0.395402
# dtype: float64

# %% [markdown]
# Almost all the features skewness has handled. Some nomial features are listed below , we will not handle their skewness.
#
# - month
# - medianamnt_loans90
# - maxamnt_loands90
# - medianamnt_loans30
# - fr_da_rech90
# - cnt-da_rech90

# %%
### 'fr_ma_rech30' skewness handle with power transformer
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
df_new['fr_ma_rech30']=pt.fit_transform(df_new['fr_ma_rech30'].values.reshape(-1,1))
df_new['medianmarechprebal30']=pt.fit_transform(df_new['medianmarechprebal30'].values.reshape(-1,1))

# %%
df_new.skew()
# Out:
# label                   -2.186101
# daily_decr90             0.442361
# rental90                 0.202705
# last_rech_amt_ma        -0.577155
# fr_ma_rech30             0.001389
# sumamnt_ma_rech30       -0.423210
# medianamnt_ma_rech30    -0.715236
# medianmarechprebal30     0.860463
# cnt_ma_rech90           -0.557688
# sumamnt_ma_rech90       -0.297338
# medianamnt_ma_rech90    -0.758152
# medianmarechprebal90    -0.264553
# cnt_da_rech90           27.928307
# fr_da_rech90            30.136185
# medianamnt_loans30       4.531760
# amnt_loans90             0.378695
# maxamnt_loans90          1.844849
# medianamnt_loans90       4.865652
# month                    0.395402
# dtype: float64

# %%
df_new.head()
# Out:
#    label  daily_decr90   rental90  last_rech_amt_ma  fr_ma_rech30  \
# 0      0     14.526152   6.383568         11.545503      1.257058
# 1      1     22.973347  15.454616         17.953584     -1.195277
# 2      1     11.181560   9.655359         11.545503     -1.195277
# 3      1      2.768873   5.422267          9.820117     -1.195277
# 4      1      5.320595  10.319359         13.217256      0.454040
#
#    sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 0          14.546423             11.545503             -0.284438
# 1          17.953584             17.953584              0.256627
# 2          11.545503             11.545503              0.283298
# 3           0.000000              0.000000             -1.054658
# 4          27.157290             13.217256              0.036578
#
#    cnt_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0       1.259921          14.546423             11.545503
# 1       1.000000          17.953584             17.953584
# 2       1.000000          11.545503             11.545503
# 3       1.000000           9.820117              9.820117
# 4       2.000000          28.641646             14.240735
#
#    medianmarechprebal90  cnt_da_rech90  fr_da_rech90  medianamnt_loans30  \
# 0              1.957434              0             0                 0.0
# 1              3.937357              0             0                 0.0
# 2              4.047761              0             0                 0.0
# 3              1.357209              0             0                 0.0
# 4              3.271066              0             0                 0.0
#
#    amnt_loans90  maxamnt_loans90  medianamnt_loans90  month
# 0      2.289428                6                 0.0      7
# 1      2.289428               12                 0.0      8
# 2      1.817121                6                 0.0      8
# 3      2.289428                6                 0.0      6
# 4      3.476027                6                 0.0      6

# %% [markdown]
# ### Checking Distribution Through Graph

# %%
## plotting graph for checking skewness.
plt.figure(figsize=(13,40))
plotnumber=1
for column in df_new.columns:
    if plotnumber<=30 :
        ax=plt.subplot(15,2,plotnumber)
        sns.distplot(x=df_new[column],color='purple',kde_kws={"color": "k", "lw": 2, "label": "KDE"})
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# quite find distribution Now. Let's go ahead.

# %% [markdown]
# ### Splitting And Standarization:

# %%
## splitting  target and feature
x=df_new.drop('label',axis=1)
y=df_new['label']
x.isna().sum()
# Out:
# daily_decr90            0
# rental90                0
# last_rech_amt_ma        0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech90           0
# fr_da_rech90            0
# medianamnt_loans30      0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# month                   0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
## scalling:-
for i in x.columns:
    x[i]=scaler.fit_transform(x[i].values.reshape(-1,1))
x.head()
# Out:
#    daily_decr90  rental90  last_rech_amt_ma  fr_ma_rech30  sumamnt_ma_rech30  \
# 0      0.329122 -0.681137          0.174601      1.257058          -0.113046
# 1      1.288208  0.604922          1.528458     -1.195277           0.308601
# 2     -0.050620 -0.217275          0.174601     -1.195277          -0.484418
# 3     -1.005788 -0.817426         -0.189927     -1.195277          -1.913208
# 4     -0.716068 -0.123135          0.527798      0.454040           1.447586
#
#    medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 0              0.299680             -0.284438      -0.365377
# 1              1.626667              0.256627      -0.734654
# 2              0.299680              0.283298      -0.734654
# 3             -2.091166             -1.054658      -0.734654
# 4              0.645867              0.036578       0.686075
#
#    sumamnt_ma_rech90  medianamnt_ma_rech90  medianmarechprebal90  \
# 0          -0.395488              0.250285             -0.630617
# 1          -0.017705              1.686236              0.330673
# 2          -0.728226              0.250285              0.384276
# 3          -0.919536             -0.136347             -0.922038
# 4           1.167376              0.854244              0.007176
#
#    cnt_da_rech90  fr_da_rech90  medianamnt_loans30  amnt_loans90  \
# 0      -0.104831     -0.046626           -0.249005     -0.302380
# 1      -0.104831     -0.046626           -0.249005     -0.302380
# 2      -0.104831     -0.046626           -0.249005     -0.929700
# 3      -0.104831     -0.046626           -0.249005     -0.302380
# 4      -0.104831     -0.046626           -0.249005      1.273661
#
#    maxamnt_loans90  medianamnt_loans90     month
# 0        -0.301679           -0.231408  0.319308
# 1         2.732499           -0.231408  1.684466
# 2        -0.301679           -0.231408  1.684466
# 3        -0.301679           -0.231408 -1.045851
# 4        -0.301679           -0.231408 -1.045851

# %% [markdown]
# ## Model Building

# %%
y.value_counts()
# Out:
# 1    170859
# 0     25778
# Name: label, dtype: int64

# %% [markdown]
# Our dataset is imbalanced dataset. We have to handle it. We have SMOTE technique for handle this kind of problems.

# %%
# importing smote

from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
# importing train test 
from sklearn.model_selection import train_test_split

# %%
### importing the models
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier
etc=ExtraTreesClassifier()
rf=RandomForestClassifier()
adc=AdaBoostClassifier()
gbdt=GradientBoostingClassifier()
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()

#### importing metrics
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix,classification_report

### importing curve metrics
from sklearn.metrics import roc_curve,auc,roc_auc_score

## importing cross validation
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Define A Function For Finding The Best Random State

# %%
def Best_random_state(model,feature,target):
    minimum=0
    for i in range(1,21):
        x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.25,random_state=i)
        over_sampling=SMOTE(0.80)
        x_train_new,y_train_new=over_sampling.fit_resample(x_train,y_train)
        model.fit(x_train_new,y_train_new)
        train=model.predict(x_train)
        test=model.predict(x_test)
        roc_score=roc_auc_score(y_test,test)
        print("Random State : ", i)
        print("The ROC_AUC Score is : ", roc_score)
        print('\n')
        if roc_score>minimum:
            
            minimum=roc_score
            j=i
    return j

# %% [markdown]
# ## Define A Function For Evaluation

# %%
def print_score(Model,independent,dependent,i,train=True):
    x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.25,random_state=i)
    over_sampling=SMOTE(0.80)
    x_train_new,y_train_new=over_sampling.fit_resample(x_train,y_train)
    Model.fit(x_train_new,y_train_new)
    if train:
        prediction=Model.predict(x_train_new)
        print('After Oversampling the  new shape of Xtrain is : ',x_train_new.shape)
        print("After oversampling the new shape of Ytrain is : ",y_train_new.shape)
        print("\n********************Traning Scores****************************\n")
        print("Accuracy Score is {} for Training Model.".format(accuracy_score(y_train_new,prediction)))
        print("\n F1 Score for the model is : \n", f1_score(y_train_new,prediction))
        print("\n*******************Confusion Matrix***************************\n")
        print(confusion_matrix(y_train_new,prediction))
        print("\n\n Training Classification Report \n",classification_report(y_train_new,prediction))
    
    if train==False:
        pred=Model.predict(x_test)
        print("\n\n")
        print("***********************Testing Scores******************************\n")
        print("Accuracy score for testing is : ", accuracy_score(y_test,pred))
        print("\n F1 Score for testing is : ", f1_score(y_test,pred))
        print("Confusion Matrix : \n",confusion_matrix(y_test,pred))
        print("\n The Classification report for Testing \n", classification_report(y_test,pred))

# %% [markdown]
# ## Define A Function For Cross Validation

# %%
def Cross_validation(clf,X,Y,Best_RandomState):
    x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=Best_RandomState)
    over_sampling=SMOTE(0.80)
    x_train_new,y_train_new=over_sampling.fit_resample(x_train,y_train)
    clf.fit(x_train_new,y_train_new)
    pred_y=clf.predict(x_test)
    for i in range(2,11):
        score=cross_val_score(clf,X,Y,cv=i)
        mean=score.mean()
        print("\nAt Random State {}, the cross validation score of the model is {}. And accuracy Score is {} ".format(i,mean,accuracy_score(y_test,pred_y)))
        print("\n The difference between corss val score and Accuaracy score is : ", mean-accuracy_score(y_test,pred_y))

# %% [markdown]
# ## 1. Logistic Regression:

# %%
## finding the best random State:

Best_random_state(lr,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7508790359322217
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7487017063939769
#
#
# Random State :  3
# The ROC_AUC Score is :  0.751065270131418
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7475449846334796
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7552779308284959
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7496209058435285
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7524365250079624
#
#
# Random State :  8
# The ROC_AUC Score is :  0.751644456444321
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7526200579849787
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7499563620403686
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7528091626459323
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7552266943009455
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7518631493824136
#
#
# Random State :  14
# The ROC_AUC Score is :  0.7525696467432241
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7496620170979368
#
#
# Random State :  16
# The ROC_AUC Score is :  0.7516178888292155
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7522566667524269
#
#
# Random State :  18
# The ROC_AUC Score is :  0.7507931081950445
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7548899502812514
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7519509673315834
# 5

# %%
## printing scores
print(print_score(lr,x,y,5,train=True))
print(print_score(lr,x,y,5,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230693, 18)
# After oversampling the new shape of Ytrain is :  (230693,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.7568760213790622 for Training Model.
#
#  F1 Score for the model is :
#  0.7812016025528495
#
# *******************Confusion Matrix***************************
#
# [[ 74479  28051]
#  [ 28036 100127]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73    102530
#            1       0.78      0.78      0.78    128163
#
#     accuracy                           0.76    230693
#    macro avg       0.75      0.75      0.75    230693
# weighted avg       0.76      0.76      0.76    230693
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.7756916192026038
#
#  F1 Score for testing is :  0.8583903735761342
# Confusion Matrix :
#  [[ 4712  1752]
#  [ 9275 33421]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.34      0.73      0.46      6464
#            1       0.95      0.78      0.86     42696
#
#     accuracy                           0.78     49160
#    macro avg       0.64      0.76      0.66     49160
# weighted avg       0.87      0.78      0.81     49160
#
# None

# %%
## checking cross validation
Cross_validation(lr,x,y,5)
# Out:
# At Random State 2, the cross validation score of the model is 0.8742454417789879. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09904202436645737
#
# At Random State 3, the cross validation score of the model is 0.8745302272135943. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09932680980106379
#
# At Random State 4, the cross validation score of the model is 0.87459124951166. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09938783209912949
#
# At Random State 5, the cross validation score of the model is 0.8745403955884445. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09933697817591403
#
# At Random State 6, the cross validation score of the model is 0.8745912588674946. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09938784145496404
#
# At Random State 7, the cross validation score of the model is 0.874535311258817. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09933189384628649
#
# At Random State 8, the cross validation score of the model is 0.874637020045723. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09943360263319245
#
# At Random State 9, the cross validation score of the model is 0.8745454845473559. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09934206713482541
#
# At Random State 10, the cross validation score of the model is 0.8745810858759355. And accuracy Score is 0.7752034174125305
#
#  The difference between corss val score and Accuaracy score is :  0.09937766846340501

# %% [markdown]
# ## 2. K-Nearest Neighbors:

# %%
## finding the best random State:

Best_random_state(knn,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7565461035333995
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7583471046296245
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7600937366696122
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7602658099713158
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7603183286815192
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7606645434053584
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7591980076968757
#
#
# Random State :  8
# The ROC_AUC Score is :  0.7583721454340777
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7569355682049328
#
#
# Random State :  10
# The ROC_AUC Score is :  0.760146530533111
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7567233763754382
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7651051935066433
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7594317155680335
#
#
# Random State :  14
# The ROC_AUC Score is :  0.7575761535794859
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7578257179154793
#
#
# Random State :  16
# The ROC_AUC Score is :  0.7599724749506622
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7594836555718767
#
#
# Random State :  18
# The ROC_AUC Score is :  0.761052179564688
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7557064990724636
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7596296426566775
# 12

# %%
## printing scores
print(print_score(knn,x,y,12,train=True))
print(print_score(knn,x,y,12,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230783, 18)
# After oversampling the new shape of Ytrain is :  (230783,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.9241148611466182 for Training Model.
#
#  F1 Score for the model is :
#  0.9275864492840514
#
# *******************Confusion Matrix***************************
#
# [[101103   1467]
#  [ 16046 112167]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92    102570
#            1       0.99      0.87      0.93    128213
#
#     accuracy                           0.92    230783
#    macro avg       0.93      0.93      0.92    230783
# weighted avg       0.93      0.92      0.92    230783
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8105370219690805
#
#  F1 Score for testing is :  0.8834176137786012
# Confusion Matrix :
#  [[ 4557  1957]
#  [ 7357 35289]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.38      0.70      0.49      6514
#            1       0.95      0.83      0.88     42646
#
#     accuracy                           0.81     49160
#    macro avg       0.66      0.76      0.69     49160
# weighted avg       0.87      0.81      0.83     49160
#
# None

# %%
## checking cross validation
Cross_validation(knn,x,y,12)
# Out:
# At Random State 2, the cross validation score of the model is 0.8979439286838782. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.08838331029494406
#
# At Random State 3, the cross validation score of the model is 0.899164451027152. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.08960383263821792
#
# At Random State 4, the cross validation score of the model is 0.9000493298294399. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09048871144050574
#
# At Random State 5, the cross validation score of the model is 0.9002324121654401. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09067179377650603
#
# At Random State 6, the cross validation score of the model is 0.9000798502467638. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09051923185782973
#
# At Random State 7, the cross validation score of the model is 0.9003239471716921. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09076332878275795
#
# At Random State 8, the cross validation score of the model is 0.9004816088694394. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09092099048050528
#
# At Random State 9, the cross validation score of the model is 0.9003290474522908. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09076842906335669
#
# At Random State 10, the cross validation score of the model is 0.900369726380562. And accuracy Score is 0.8095606183889341
#
#  The difference between corss val score and Accuaracy score is :  0.09080910799162789

# %% [markdown]
# ## 3. Decision Tree Classifier:

# %%
## finding the best random State:

Best_random_state(dt,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7331522902855011
#
#
# Random State :  2
# The ROC_AUC Score is :  0.729904566515024
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7327278554515908
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7338274400111806
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7348918795231125
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7330489651368843
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7348289940897017
#
#
# Random State :  8
# The ROC_AUC Score is :  0.734428389691565
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7396519788753999
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7339921362247127
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7314545078505559
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7353446761106506
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7391332933957763
#
#
# Random State :  14
# The ROC_AUC Score is :  0.7414719788586809
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7350542470232095
#
#
# Random State :  16
# The ROC_AUC Score is :  0.7339610093025994
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7370650547894366
#
#
# Random State :  18
# The ROC_AUC Score is :  0.7329375956700617
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7386129903084753
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7401484375114495
# 14

# %%
## printing scores
print(print_score(dt,x,y,14,train=True))
print(print_score(dt,x,y,14,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230668, 18)
# After oversampling the new shape of Ytrain is :  (230668,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.9987471170686875 for Training Model.
#
#  F1 Score for the model is :
#  0.9988712128017748
#
# *******************Confusion Matrix***************************
#
# [[102510      9]
#  [   280 127869]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    102519
#            1       1.00      1.00      1.00    128149
#
#     accuracy                           1.00    230668
#    macro avg       1.00      1.00      1.00    230668
# weighted avg       1.00      1.00      1.00    230668
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8476810414971522
#
#  F1 Score for testing is :  0.9101058848951955
# Confusion Matrix :
#  [[ 3767  2683]
#  [ 4805 37905]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.44      0.58      0.50      6450
#            1       0.93      0.89      0.91     42710
#
#     accuracy                           0.85     49160
#    macro avg       0.69      0.74      0.71     49160
# weighted avg       0.87      0.85      0.86     49160
#
# None

# %%
## checking cross validation
Cross_validation(dt,x,y,14)
# Out:
# At Random State 2, the cross validation score of the model is 0.8655695478239764. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.016708685334147266
#
# At Random State 3, the cross validation score of the model is 0.8644507378274349. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.015589875337605696
#
# At Random State 4, the cross validation score of the model is 0.8647050207103497. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.015844158220520543
#
# At Random State 5, the cross validation score of the model is 0.8653712415365332. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.01651037904670405
#
# At Random State 6, the cross validation score of the model is 0.8647151933845612. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.015854330894731983
#
# At Random State 7, the cross validation score of the model is 0.8650610007272282. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.016200138237399075
#
# At Random State 8, the cross validation score of the model is 0.8650101403733255. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.016149277883496294
#
# At Random State 9, the cross validation score of the model is 0.8653508852637386. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.01649002277390943
#
# At Random State 10, the cross validation score of the model is 0.8648576029489909. And accuracy Score is 0.8488608624898292
#
#  The difference between corss val score and Accuaracy score is :  0.015996740459161773

# %% [markdown]
# ## 4. Random Forest Classifier:

# %%
## finding the best random State:

Best_random_state(rf,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7592943592084302
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7548657432529926
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7605256901754955
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7575832640372571
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7559105114769488
#
#
# Random State :  6
# The ROC_AUC Score is :  0.750628144304631
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7608748719414298
#
#
# Random State :  8
# The ROC_AUC Score is :  0.7575460904070207
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7571217880313926
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7547924200944708
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7576195083712266
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7614649004864879
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7566466033535924
#
#
# Random State :  14
# The ROC_AUC Score is :  0.758033882739006
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7552356560219096
#
#
# Random State :  16
# The ROC_AUC Score is :  0.757427823510334
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7598550216464963
#
#
# Random State :  18
# The ROC_AUC Score is :  0.75447392675868
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7579775274207851
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7567987633749107
# 12

# %%
## printing scores
print(print_score(rf,x,y,12,train=True))
print(print_score(rf,x,y,12,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230783, 18)
# After oversampling the new shape of Ytrain is :  (230783,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.9987520744595573 for Training Model.
#
#  F1 Score for the model is :
#  0.9988757816830486
#
# *******************Confusion Matrix***************************
#
# [[102550     20]
#  [   268 127945]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    102570
#            1       1.00      1.00      1.00    128213
#
#     accuracy                           1.00    230783
#    macro avg       1.00      1.00      1.00    230783
# weighted avg       1.00      1.00      1.00    230783
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8972742066720911
#
#  F1 Score for testing is :  0.9411394470604689
# Confusion Matrix :
#  [[ 3737  2777]
#  [ 2273 40373]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.62      0.57      0.60      6514
#            1       0.94      0.95      0.94     42646
#
#     accuracy                           0.90     49160
#    macro avg       0.78      0.76      0.77     49160
# weighted avg       0.89      0.90      0.90     49160
#
# None

# %%
## checking cross validation
Cross_validation(rf,x,y,12)
# Out:
# At Random State 2, the cross validation score of the model is 0.9076369173048896. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.00971177491270081
#
# At Random State 3, the cross validation score of the model is 0.9075199473505878. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.009594804958399039
#
# At Random State 4, the cross validation score of the model is 0.9077132046746372. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.00978806228244844
#
# At Random State 5, the cross validation score of the model is 0.9077081157407887. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.0097829733485999
#
# At Random State 6, the cross validation score of the model is 0.9076877770279959. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.009762634635807066
#
# At Random State 7, the cross validation score of the model is 0.907535204463046. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.00961006207085724
#
# At Random State 8, the cross validation score of the model is 0.9077793103395766. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.009854167947387804
#
# At Random State 9, the cross validation score of the model is 0.9074538515711544. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.009528709178965644
#
# At Random State 10, the cross validation score of the model is 0.9076979439292516. And accuracy Score is 0.8979251423921888
#
#  The difference between corss val score and Accuaracy score is :  0.009772801537062836

# %% [markdown]
# ## 5. Ada Boost Classifier:

# %%
## finding the best random State:

Best_random_state(adc,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7876980718897819
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7841279665224958
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7880830145421586
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7846073625442668
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7901014476974679
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7856406748953402
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7900533810384268
#
#
# Random State :  8
# The ROC_AUC Score is :  0.790502626386917
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7927673797844611
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7858474768838337
#
#
# Random State :  11
# The ROC_AUC Score is :  0.79055402246983
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7982739343833133
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7868284748052614
#
#
# Random State :  14
# The ROC_AUC Score is :  0.785946631237533
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7829819682044208
#
#
# Random State :  16
# The ROC_AUC Score is :  0.7879453693125772
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7937942695272722
#
#
# Random State :  18
# The ROC_AUC Score is :  0.784964870523092
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7881677387344208
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7948791000394231
# 12

# %%
## printing scores
print(print_score(adc,x,y,12,train=True))
print(print_score(adc,x,y,12,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230783, 18)
# After oversampling the new shape of Ytrain is :  (230783,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.8235615274955261 for Training Model.
#
#  F1 Score for the model is :
#  0.8399894685963761
#
# *******************Confusion Matrix***************************
#
# [[ 83185  19385]
#  [ 21334 106879]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80    102570
#            1       0.85      0.83      0.84    128213
#
#     accuracy                           0.82    230783
#    macro avg       0.82      0.82      0.82    230783
# weighted avg       0.82      0.82      0.82    230783
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8245321399511798
#
#  F1 Score for testing is :  0.8920616647479854
# Confusion Matrix :
#  [[ 4889  1625]
#  [ 7001 35645]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.41      0.75      0.53      6514
#            1       0.96      0.84      0.89     42646
#
#     accuracy                           0.82     49160
#    macro avg       0.68      0.79      0.71     49160
# weighted avg       0.88      0.82      0.84     49160
#
# None

# %%
## checking cross validation
Cross_validation(adc,x,y,12)
# Out:
# At Random State 2, the cross validation score of the model is 0.9029887597043869. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08317590372391492
#
# At Random State 3, the cross validation score of the model is 0.9039702549758458. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08415739899537389
#
# At Random State 4, the cross validation score of the model is 0.9036498701693817. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08383701418890976
#
# At Random State 5, the cross validation score of the model is 0.9035532470719778. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08374039109150588
#
# At Random State 6, the cross validation score of the model is 0.9035939385485986. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08378108256812666
#
# At Random State 7, the cross validation score of the model is 0.9037566683787893. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08394381239831739
#
# At Random State 8, the cross validation score of the model is 0.9032125265301691. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08339967054969721
#
# At Random State 9, the cross validation score of the model is 0.9037515785229182. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08393872254244628
#
# At Random State 10, the cross validation score of the model is 0.9037973506451902. And accuracy Score is 0.8198128559804719
#
#  The difference between corss val score and Accuaracy score is :  0.08398449466471825

# %% [markdown]
# ## 6. Gradient Boosting Classifier:

# %%
## finding the best random State:

Best_random_state(gbdt,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7959937798605561
#
#
# Random State :  2
# The ROC_AUC Score is :  0.793373142915488
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7961843940054056
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7913072525816781
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7992800413051423
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7950416171713124
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7974860097772227
#
#
# Random State :  8
# The ROC_AUC Score is :  0.7966352702683264
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7955593926564458
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7925792893115355
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7983866442199775
#
#
# Random State :  12
# The ROC_AUC Score is :  0.8005477104634363
#
#
# Random State :  13
# The ROC_AUC Score is :  0.793961195342242
#
#
# Random State :  14
# The ROC_AUC Score is :  0.7971676295332321
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7921554199867964
#
#
# Random State :  16
# The ROC_AUC Score is :  0.79563469389958
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7963505616367896
#
#
# Random State :  18
# The ROC_AUC Score is :  0.7967263254471477
#
#
# Random State :  19
# The ROC_AUC Score is :  0.8006838634783643
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7989124938996778
# 19

# %%
## printing scores
print(print_score(gbdt,x,y,19,train=True))
print(print_score(gbdt,x,y,19,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230797, 18)
# After oversampling the new shape of Ytrain is :  (230797,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.8626281970736188 for Training Model.
#
#  F1 Score for the model is :
#  0.8770118197440543
#
# *******************Confusion Matrix***************************
#
# [[ 86050  16526]
#  [ 15179 113042]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84    102576
#            1       0.87      0.88      0.88    128221
#
#     accuracy                           0.86    230797
#    macro avg       0.86      0.86      0.86    230797
# weighted avg       0.86      0.86      0.86    230797
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8620626525630594
#
#  F1 Score for testing is :  0.9175351761543982
# Confusion Matrix :
#  [[ 4655  1867]
#  [ 4914 37724]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.49      0.71      0.58      6522
#            1       0.95      0.88      0.92     42638
#
#     accuracy                           0.86     49160
#    macro avg       0.72      0.80      0.75     49160
# weighted avg       0.89      0.86      0.87     49160
#
# None

# %%
## checking cross validation
Cross_validation(gbdt,x,y,19)
# Out:
# At Random State 2, the cross validation score of the model is 0.9094219312205414. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04658629248986601
#
# At Random State 3, the cross validation score of the model is 0.9097321480999252. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04689650936924983
#
# At Random State 4, the cross validation score of the model is 0.9098491186442703. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04701347991359495
#
# At Random State 5, the cross validation score of the model is 0.9096965598710509. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.046860921140375544
#
# At Random State 6, the cross validation score of the model is 0.9095592419992252. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04672360326854985
#
# At Random State 7, the cross validation score of the model is 0.9099253955257657. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04708975679509031
#
# At Random State 8, the cross validation score of the model is 0.9097118103111896. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04687617158051427
#
# At Random State 9, the cross validation score of the model is 0.9096406167396138. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04680497800893846
#
# At Random State 10, the cross validation score of the model is 0.9098491076365811. And accuracy Score is 0.8628356387306754
#
#  The difference between corss val score and Accuaracy score is :  0.04701346890590574

# %% [markdown]
# ## 7. Naive Bayes Classifier:

# %%
## finding the best random State:

Best_random_state(gnb,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7470741508765976
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7427632394322073
#
#
# Random State :  3
# The ROC_AUC Score is :  0.7467112723922062
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7423945146022127
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7468451551099461
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7434607041460709
#
#
# Random State :  7
# The ROC_AUC Score is :  0.7458687076287477
#
#
# Random State :  8
# The ROC_AUC Score is :  0.7446845218928282
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7462002383258175
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7447143975269931
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7461425538315573
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7492099455527162
#
#
# Random State :  13
# The ROC_AUC Score is :  0.7466100999194913
#
#
# Random State :  14
# The ROC_AUC Score is :  0.749147359422389
#
#
# Random State :  15
# The ROC_AUC Score is :  0.7412354489086797
#
#
# Random State :  16
# The ROC_AUC Score is :  0.742019838940184
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7426204694784344
#
#
# Random State :  18
# The ROC_AUC Score is :  0.7471285183922215
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7503399571633189
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7461466114450107
# 19

# %%
## printing scores
print(print_score(gnb,x,y,19,train=True))
print(print_score(gnb,x,y,19,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230797, 18)
# After oversampling the new shape of Ytrain is :  (230797,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.751959514205124 for Training Model.
#
#  F1 Score for the model is :
#  0.778595545379656
#
# *******************Confusion Matrix***************************
#
# [[ 72892  29684]
#  [ 27563 100658]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72    102576
#            1       0.77      0.79      0.78    128221
#
#     accuracy                           0.75    230797
#    macro avg       0.75      0.75      0.75    230797
# weighted avg       0.75      0.75      0.75    230797
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.780187144019528
#
#  F1 Score for testing is :  0.8619359125057494
# Confusion Matrix :
#  [[ 4623  1899]
#  [ 8907 33731]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.34      0.71      0.46      6522
#            1       0.95      0.79      0.86     42638
#
#     accuracy                           0.78     49160
#    macro avg       0.64      0.75      0.66     49160
# weighted avg       0.87      0.78      0.81     49160
#
# None

# %%
## checking cross validation
Cross_validation(gnb,x,y,19)
# Out:
# At Random State 2, the cross validation score of the model is 0.8142923401634099. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03414587962638793
#
# At Random State 3, the cross validation score of the model is 0.8143584483607927. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03421198782377077
#
# At Random State 4, the cross validation score of the model is 0.8144296337174017. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03428317318037977
#
# At Random State 5, the cross validation score of the model is 0.8143177637468885. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.0341713032098665
#
# At Random State 6, the cross validation score of the model is 0.8141245230034443. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03397806246642232
#
# At Random State 7, the cross validation score of the model is 0.8143024964782822. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.034156035941260265
#
# At Random State 8, the cross validation score of the model is 0.8142414925192147. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03409503198219277
#
# At Random State 9, the cross validation score of the model is 0.8142008226162798. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03405436207925783
#
# At Random State 10, the cross validation score of the model is 0.8142262364433048. And accuracy Score is 0.780146460537022
#
#  The difference between corss val score and Accuaracy score is :  0.03407977590628286

# %% [markdown]
# ## 8. Extra Tree Classifier:

# %%
## finding the best random State:

Best_random_state(etc,x,y)
# Out:
# Random State :  1
# The ROC_AUC Score is :  0.7513809353366326
#
#
# Random State :  2
# The ROC_AUC Score is :  0.7470763223021326
#
#
# Random State :  3
# The ROC_AUC Score is :  0.751514231903337
#
#
# Random State :  4
# The ROC_AUC Score is :  0.7480219311297649
#
#
# Random State :  5
# The ROC_AUC Score is :  0.7488268430553005
#
#
# Random State :  6
# The ROC_AUC Score is :  0.7436055077587294
#
#
# Random State :  7
# The ROC_AUC Score is :  0.750340769238341
#
#
# Random State :  8
# The ROC_AUC Score is :  0.7497098083130375
#
#
# Random State :  9
# The ROC_AUC Score is :  0.7491265294087932
#
#
# Random State :  10
# The ROC_AUC Score is :  0.7468474754676578
#
#
# Random State :  11
# The ROC_AUC Score is :  0.7466998883450774
#
#
# Random State :  12
# The ROC_AUC Score is :  0.7515120373708418
#
#
# Random State :  13
# The ROC_AUC Score is :  0.748803118695256
#
#
# Random State :  14
# The ROC_AUC Score is :  0.750023123317706
#
#
# Random State :  15
# The ROC_AUC Score is :  0.747922839226506
#
#
# Random State :  16
# The ROC_AUC Score is :  0.7488250207946734
#
#
# Random State :  17
# The ROC_AUC Score is :  0.7503703620128148
#
#
# Random State :  18
# The ROC_AUC Score is :  0.7448870561933985
#
#
# Random State :  19
# The ROC_AUC Score is :  0.7491629754576223
#
#
# Random State :  20
# The ROC_AUC Score is :  0.7480784168033288
# 3

# %%
## printing scores
print(print_score(etc,x,y,3,train=True))
print(print_score(etc,x,y,3,train=False))
# Out:
# After Oversampling the  new shape of Xtrain is :  (230623, 18)
# After oversampling the new shape of Ytrain is :  (230623,)
#
# ********************Traning Scores****************************
#
# Accuracy Score is 0.9987598808444951 for Training Model.
#
#  F1 Score for the model is :
#  0.9988827164834478
#
# *******************Confusion Matrix***************************
#
# [[102491      8]
#  [   278 127846]]
#
#
#  Training Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    102499
#            1       1.00      1.00      1.00    128124
#
#     accuracy                           1.00    230623
#    macro avg       1.00      1.00      1.00    230623
# weighted avg       1.00      1.00      1.00    230623
#
# None
#
#
#
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8963791700569569
#
#  F1 Score for testing is :  0.9408087380897049
# Confusion Matrix :
#  [[ 3583  2842]
#  [ 2252 40483]]
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.61      0.56      0.58      6425
#            1       0.93      0.95      0.94     42735
#
#     accuracy                           0.90     49160
#    macro avg       0.77      0.75      0.76     49160
# weighted avg       0.89      0.90      0.89     49160
#
# None

# %%
## checking cross validation
Cross_validation(etc,x,y,3)
# Out:
# At Random State 2, the cross validation score of the model is 0.9039295785304408. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.008181002452328445
#
# At Random State 3, the cross validation score of the model is 0.9043618438398949. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.008613267761782617
#
# At Random State 4, the cross validation score of the model is 0.9043364210057099. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.008587844927597565
#
# At Random State 5, the cross validation score of the model is 0.9043771098343131. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.008628533756200762
#
# At Random State 6, the cross validation score of the model is 0.9046720659902631. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.00892348991215075
#
# At Random State 7, the cross validation score of the model is 0.9045347518523981. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.008786175774285754
#
# At Random State 8, the cross validation score of the model is 0.904931432632281. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.009182856554168728
#
# At Random State 9, the cross validation score of the model is 0.9048805950515995. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.009132018973487144
#
# At Random State 10, the cross validation score of the model is 0.9046059589125587. And accuracy Score is 0.8957485760781123
#
#  The difference between corss val score and Accuaracy score is :  0.00885738283444637

# %% [markdown]
# ##  Random Forest Classifier Gives us the Best Accuracy.

# %% [markdown]
# # Hyperper ParaMeter Tunning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=12)
over_sampling=SMOTE(0.80)
x_train_new,y_train_new=over_sampling.fit_resample(x_train,y_train)
rf.fit(x_train_new,y_train_new)
# Out:
# RandomForestClassifier()

# %%
grid_param={'n_estimators':[50,100,200],
            'criterion':["gini","entropy","log_loss"],
           'max_depth':list(range(3,8))}

# %%
grid=GridSearchCV(RandomForestClassifier(),grid_param,cv=2,n_jobs=-1)
grid.fit(x_train_new,y_train_new)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'n_estimators': [50, 100, 200]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'n_estimators': 200}

# %% [markdown]
# ## Model Evaluation

# %%
rf=RandomForestClassifier(n_estimators=200,criterion="gini",max_depth=7)

rf.fit(x_train_new,y_train_new)
y_pred=rf.predict(x_test)
print("\n\n")
print("***********************Testing Scores******************************\n")
print("Accuracy score for testing is : ", accuracy_score(y_test,y_pred))
print("\n F1 Score for testing is : ", f1_score(y_test,y_pred))

matrix=confusion_matrix(y_test,y_pred)
print("Confusion Matrix : \n",matrix)
true_positive=matrix[0][0]
false_positive=matrix[0][1]
false_negative=matrix[1][0]
true_negative=matrix[1][1]
print("True positives are :- " ,true_positive)
print("False positives are :- " ,false_positive)
print("False negatives are :- " ,false_negative)
print("True negatives are :- " ,true_negative)
print("\n The Classification report for Testing \n", classification_report(y_test,y_pred))
# Out:
# ***********************Testing Scores******************************
#
# Accuracy score for testing is :  0.8237794955248169
#
#  F1 Score for testing is :  0.8917355062049315
# Confusion Matrix :
#  [[ 4820  1694]
#  [ 6969 35677]]
# True positives are :-  4820
# False positives are :-  1694
# False negatives are :-  6969
# True negatives are :-  35677
#
#  The Classification report for Testing
#                precision    recall  f1-score   support
#
#            0       0.41      0.74      0.53      6514
#            1       0.95      0.84      0.89     42646
#
#     accuracy                           0.82     49160
#    macro avg       0.68      0.79      0.71     49160
# weighted avg       0.88      0.82      0.84     49160

# %% [markdown]
# ## Roc AUC Curve:

# %%
from sklearn.metrics import roc_curve,auc
fpr, tpr, threshold= roc_curve(y_pred,y_test)
plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC curve")
plt.show()
print("AUC value is {} ".format(auc(fpr, tpr)))
# Out:
# AUC value is 0.6817632234721752

# %% [markdown]
# ## Actual Vs Predicted:

# %%
original=np.array(y_test)
predicted=np.array(rf.predict(x_test))
compare=pd.DataFrame({'Actual':original,'Predicted':predicted},index=range(len(original)))
compare
# Out:
#        Actual  Predicted
# 0           1          1
# 1           1          1
# 2           1          1
# 3           1          1
# 4           1          0
# ...       ...        ...
# 49155       0          0
# 49156       1          1
# 49157       1          1
# 49158       1          0
# 49159       1          1
#
# [49160 rows x 2 columns]

# %% [markdown]
# ## Saving The Model:

# %%
import joblib
joblib.dump(rf,'Micro_Credit_project_Model')
# Out:
# ['Micro_Credit_project_Model']
