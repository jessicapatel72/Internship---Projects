# %% [markdown]
# # E-RETAIL FACTORS FOR CUSTOMER ACTIVATION AND RETENTION

# %% [markdown]
# ## Importing the Libraries

# %%
#Import libraries 

import pandas as pd #Data processing
import numpy as np #Linear algebra
from sklearn.preprocessing import StandardScaler #resize the distribution of values
from sklearn.linear_model import LinearRegression #algorithm
from sklearn.model_selection import train_test_split #estimate the performance

import matplotlib.pyplot as plt #data visualization
import seaborn as sns  #data visualization

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing all required libraries

# %% [markdown]
# ## Importing the dataset

# %%
#Loading the dataset

df= pd.read_excel("customer_retention_dataset.xlsx")
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# Importing the dataset and we can see all the columns of the dataset

# %% [markdown]
# #### This dataset is having 71 columns. We can not see it directly. so, we need to put following instruction through which we can see all the column details.

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# We can see all the columns of the dataset.

# %% [markdown]
# ## Basic Information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# This instruction gives us basic information about all columns.
#
# The dataset has 269 rows, 71 columns(variables).

# %% [markdown]
# ## Datatypes of all columns

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# We have integer data type only in one column ==> What is the Pin Code of where you shop online from?
#
# Rest all are having object data type.

# %% [markdown]
# ## Checking for null values

# %%
#checking is there any null values present in the dataset
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# We can see There are NO missing values in dataset. So, we can proceed further safely.

# %% [markdown]
# ## Visualization of missing values by heatmap

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("NULL VALUES")
plt.show()

# %% [markdown]
# We can not see any missing values here. If missing value is present then it will represent with white lines.

# %%
#Renaming the columns for our convenience.
df = df.rename(
    columns={'1Gender of respondent':"Gender",
             '2 How old are you? ':"Age",
             '3 Which city do you shop online from?':"Shopping_city",
             '4 What is the Pin Code of where you shop online from?':"Pin_code_City",
             '5 Since How Long You are Shopping Online ?':"Shopping_Exp_Online",
             '6 How many times you have made an online purchase in the past 1 year?':"No_of_purchase_lastyear",
             '7 How do you access the internet while shopping on-line?':"Internet_Type",
             '8 Which device do you use to access the online shopping?':"Device_shopping",
             "9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ":"Screensize_Mobile",
             "10 What is the operating system (OS) of your device?\t\t\t\t                                          ": "Operating_system", 
             "11 What browser do you run on your device to access the website?\t\t\t                                                          ":"Browser",                                                                                                                                                                          
             '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ': "mode_of_conn_online_store ", 
             '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ' :  "Mode _of_conn_again",                      
             '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ' : "Time_duration_purchase", 
             '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ': "Payment_mode",                   
             '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ' :"Frequency_abandoning_items", 
             '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ' :"Abandoned_bag_reasons", 
             '18 The content on the website must be easy to read and understand':"content_of_website_easy_toread_understand",
             '19 Information on similar product to the one highlighted  is important for product comparison':"similar_product_comparision_imp",
             '20 Complete information on listed seller and product being offered is important for purchase decision.':"complete_info_listed_seller_product_imp_for_purchase_decision",
             '21 All relevant information on listed products must be stated clearly':"All_relevant_information_on_listed_products_must_be_stated_clearly",
             '22 Ease of navigation in website':"Ease of navigation in website",
             '23 Loading and processing speed': "loading_processing_speed",
             '24 User friendly Interface of the website':"userfriendly_interface_website",
             '25 Convenient Payment methods':"Convenient_pay_methods",
             '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':"Trust_online_store_fulfill_itspart_oftransaction_intime",
             '27 Empathy (readiness to assist with queries) towards the customers':"Readiness_to_help_customers",
             '28 Being able to guarantee the privacy of the customer': "Guarantee_privacy_of_customers",
             '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':"Customer_support_availability_by_modes",
             '30 Online shopping gives monetary benefit and discounts':"Monetary_benefits_online_shopping_discounts",
             '31 Enjoyment is derived from shopping online':"Enjoyment_from_online_shopping",
             '32 Shopping online is convenient and flexible':"onlineshopping_convenient_flexible",
             '33 Return and replacement policy of the e-tailer is important for purchase decision': "Importance_return_policy_replacement_policy",
             '34 Gaining access to loyalty programs is a benefit of shopping online':"loyality_program_benefit_shopping_online",
             '35 Displaying quality Information on the website improves satisfaction of customers':"Quality_info_website_improves_satisfaction",
             '36 User derive satisfaction while shopping on a good quality website or application':"Satisfaction_shopping_goodquality_website",
             '37 Net Benefit derived from shopping online can lead to users satisfaction':"benefit_derived_from_shopping_online_lead_users_satisfaction",
             '38 User satisfaction cannot exist without trust':"user_satisfaction_with_trust",
             '39 Offering a wide variety of listed product in several category':"wide_variety_product_category",
             '40 Provision of complete and relevant product information':"Complete_and_relevant_product_info",
             '41 Monetary savings':"Monetary_savings",
             '42 The Convenience of patronizing the online retailer':"Convenience_of_patronizing_online_retailer",
             '43 Shopping on the website gives you the sense of adventure':"Sense_of_adventure",
             '44 Shopping on your preferred e-tailer enhances your social status':"Social_status_enhancement_by_shopping_retailer",
             '45 You feel gratification shopping on your favorite e-tailer':"Gratification_feeling_favourite_retailer",
             '46 Shopping on the website helps you fulfill certain roles':"Shopping_website_helps_you_fulfill_certainroles" ,
             '47 Getting value for money spent': "Value_for_money",
             'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':"online_retailer_shopped_from" ,
             'Easy to use website or application': "easy_to_use_website_application",
             'Visual appealing web-page layout': "Visual_appealing_webpage", 
             'Wild variety of product on offer':"wild_variety_product_offer",
             'Complete, relevant description information of products':"Complete_relevant_description_about_product",
             'Fast loading website speed of website and application':"Fast loading_website_application",
             'Reliability of the website or application':"Reliability_of_website_application",
             'Quickness to complete purchase':"Quickness_shopping",
             'Availability of several payment options':"Availability_of_payment_options",
             'Speedy order delivery ':"speedy_order_delivery",
             'Privacy of customers’ information':"Privacy_of_customers",
             'Security of customer financial information':"security_of_customer_fin_info",
             'Perceived Trustworthiness':"Perceived_trustworthiness",
             'Presence of online assistance through multi-channel':"Presence_onlin_assist_multichannel",
             'Longer time to get logged in (promotion, sales period)':"Longer_time_to_get_logged_in",
             'Longer time in displaying graphics and photos (promotion, sales period)':"long_tim_displ_graphics_photos",
             'Late declaration of price (promotion, sales period)': "late_decl_of_price",
             'Longer page loading time (promotion, sales period)':"Longer_pag_load_tim",
             'Limited mode of payment on most products (promotion, sales period)':"Constraint_on_mostproducts_payment",
             'Longer delivery period':"Long_del_period", 'Change in website/Application design':"Website_&_application_change",
             'Frequent disruption when moving from one page to another':"Frequent_disruption_pageschanging",
             'Website is as efficient as before':"Efficient_website",
             'Which of the Indian online retailer would you recommend to a friend?':"Online_retailer_reccom"})

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Shopping_city', 'Pin_code_City',
#        'Shopping_Exp_Online', 'No_of_purchase_lastyear', 'Internet_Type',
#        'Device_shopping', 'Screensize_Mobile', 'Operating_system', 'Browser',
#        'mode_of_conn_online_store ', 'Mode _of_conn_again',
#        'Time_duration_purchase', 'Payment_mode', 'Frequency_abandoning_items',
#        'Abandoned_bag_reasons', 'content_of_website_easy_toread_understand',
#        'similar_product_comparision_imp',
#        'complete_info_listed_seller_product_imp_for_purchase_decision',
#        'All_relevant_information_on_listed_products_must_be_stated_clearly',
#        'Ease of navigation in website', 'loading_processing_speed',
#        'userfriendly_interface_website', 'Convenient_pay_methods',
#        'Trust_online_store_fulfill_itspart_oftransaction_intime',
#        'Readiness_to_help_customers', 'Guarantee_privacy_of_customers',
#        'Customer_support_availability_by_modes',
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Visualization (Uni Variate analysis)

# %% [markdown]
# Uni variate analysis works with only one variable, hence it is called uni variate.

# %%
#Plotting countplot and piechart for the Gender column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Gender'])
df['Gender'].value_counts()
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64

# %% [markdown]
# We can see that Female(181) respondents are more in comparison to the Male(88) respondents.

# %%
#Plotting countplot and piechart for the Age column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Age'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=45)
sns.countplot(df['Age'])
df['Age'].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64

# %% [markdown]
# From the plots we can clearly see that most of the respondents are from the following three categories:-
#
# 1. 31-40 years
# 2. 21-30 years
# 3. 41-50 years
#
# Very few respondents are from these two categories :-
#
# 1. Less than 20 years
# 2. 51 years and above.

# %%
#Plotting countplot and piechart for the Shopping_city column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Shopping_city'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=45)
sns.countplot(df['Shopping_city'])
df['Shopping_city'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: Shopping_city, dtype: int64

# %% [markdown]
# We can see that most people are ordering from Delhi & least people are ordering from Bulandshahr
#
# Shopping_cities in decreasing order:
#
# 1.Delhi > 2.Greater Noida > 3.Noida > 4.Bangalore > 5.Karnal > 6.Solan > 7.Ghaziabad > 8.Gurgaon > 9.Merrut > 10.Noradabad > 11.Bulandshahr

# %%
#Plotting countplot and piechart for the Shopping_Exp_Online column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Shopping_Exp_Online'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=45)
sns.countplot(df['Shopping_Exp_Online'])
df['Shopping_Exp_Online'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Shopping_Exp_Online, dtype: int64

# %% [markdown]
# We can see that most of the online shoppers of our dataset have more than 4 years experience
#
# Very few of the shoppers have experience of 1-2 years.

# %%
#Plotting countplot and piechart for the No_of_purchase_lastyear column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['No_of_purchase_lastyear'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=45)
sns.countplot(df['No_of_purchase_lastyear'])
df['No_of_purchase_lastyear'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: No_of_purchase_lastyear, dtype: int64

# %% [markdown]
# From the above plots we can conclude that majority people purchase less than 10 times in last one year

# %%
#Plotting countplot and piechart for the Internet_Type column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Internet_Type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Internet_Type'])
df['Internet_Type'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: Internet_Type, dtype: int64

# %% [markdown]
# From the above plots we can conclude that most of people depend on "Mobile Internet" & followed by "Wi-Fi" for the online shopping.

# %%
#Plotting countplot and piechart for the Device_shopping column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Device_shopping'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Device_shopping'])
df['Device_shopping'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: Device_shopping, dtype: int64

# %% [markdown]
# Above plots clearly say that "Smartphone" is the most popular device followed by the "Laptop".

# %%
#Plotting countplot and piechart for the Screensize_Mobile column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Screensize_Mobile'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Screensize_Mobile'])
df['Screensize_Mobile'].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: Screensize_Mobile, dtype: int64

# %% [markdown]
# The data which we have it is saying most people have screen size apart from 4.7,5.5,5 inches. But the screensize does not matter for the online shopping.

# %%
#Plotting countplot and piechart for the Payment_mode column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Payment_mode'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=45)
sns.countplot(df['Payment_mode'])
df['Payment_mode'].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: Payment_mode, dtype: int64

# %% [markdown]
# We can see that most people prefer Credit/Debit card for their payment options.
#
# After Credit/Debit card comes the Cash on Delivery(COD).
#
# Least people go with E-wallets(Paytm,Freecharge).

# %%
#Plotting countplot and piechart for the Operating_system column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Operating_system'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Operating_system'])
df['Operating_system'].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: Operating_system, dtype: int64

# %% [markdown]
# Most people are using the windows phone/windows.
#
# Very few people are using the IOS/MAC_operating_system.

# %%
#Plotting countplot and piechart for the Browser column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Browser'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Browser'])
df['Browser'].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: Browser, dtype: int64

# %% [markdown]
# We can see that mostly people use "Google_chrome" followed by "Safari".
#
# Very less people use "Mozilla Firefox" & "Opera".

# %%
#Plotting countplot and piechart for the mode_of_conn_online_store column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['mode_of_conn_online_store '].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['mode_of_conn_online_store '])
df['mode_of_conn_online_store '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: mode_of_conn_online_store , dtype: int64

# %% [markdown]
# Search Engine is the channel which is used mostly by the people for the first time to arrive at their favourite online store.

# %%
#Plotting countplot and piechart for the Mode _of_conn_again column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Mode _of_conn_again'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Mode _of_conn_again'])
df['Mode _of_conn_again'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: Mode _of_conn_again, dtype: int64

# %% [markdown]
# After first visit, mostly people again use online store via search engine or applications and then followed by direct URL. Very Less of the people are using via e-mail and social media.

# %%
#Plotting countplot and piechart for the Time_duration_purchase column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Time_duration_purchase'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Time_duration_purchase'])
df['Time_duration_purchase'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: Time_duration_purchase, dtype: int64

# %% [markdown]
# For making a purchase decision most of the people spent more than 15 mins to explore the e-retail store.

# %%
#Plotting countplot and piechart for the Frequency_abandoning_items column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Frequency_abandoning_items'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Frequency_abandoning_items'])
df['Frequency_abandoning_items'].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: Frequency_abandoning_items, dtype: int64

# %% [markdown]
# Sometimes most of the people do abandoned the items in list while shopping online.

# %%
#Plotting countplot and piechart for the Abandoned_bag_reasons column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Abandoned_bag_reasons'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.xticks(rotation=90)
sns.countplot(df['Abandoned_bag_reasons'])
df['Abandoned_bag_reasons'].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: Abandoned_bag_reasons, dtype: int64

# %% [markdown]
# Most people abandoned the items of their list because they have waited for" Better_alternative_offers" followed by "Promo code not applicable".

# %%
#Plotting countplot and piechart for the content_of_website_easy_toread_understand column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['content_of_website_easy_toread_understand'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['content_of_website_easy_toread_understand'])
df['content_of_website_easy_toread_understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: content_of_website_easy_toread_understand, dtype: int64

# %% [markdown]
# Most people strongly agree that the content must be easy to read and understand.

# %%
#Plotting countplot and piechart for the similar_product_comparision_imp column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['similar_product_comparision_imp'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['similar_product_comparision_imp'])
df['similar_product_comparision_imp'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: similar_product_comparision_imp, dtype: int64

# %% [markdown]
# Most people strongly agree that product comparision is very much important.

# %%
#Plotting countplot and piechart for the complete_info_listed_seller_product_imp_for_purchase_decision column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['complete_info_listed_seller_product_imp_for_purchase_decision'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['complete_info_listed_seller_product_imp_for_purchase_decision'])
df['complete_info_listed_seller_product_imp_for_purchase_decision'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: complete_info_listed_seller_product_imp_for_purchase_decision, dtype: int64

# %% [markdown]
# Mostly people agree and some of people strongly agree that complete information on products is important for purchase decision.

# %%
#Plotting countplot and piechart for the All_relevant_information_on_listed_products_must_be_stated_clearly column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['All_relevant_information_on_listed_products_must_be_stated_clearly'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['All_relevant_information_on_listed_products_must_be_stated_clearly'])
df['All_relevant_information_on_listed_products_must_be_stated_clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: All_relevant_information_on_listed_products_must_be_stated_clearly, dtype: int64

# %% [markdown]
# From the above plots we can say that most of the people agree with "Importance of all relevant information on listed products must be stated clearly".

# %%
#Plotting countplot and piechart for the Ease of navigation in website column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Ease of navigation in website'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Ease of navigation in website'])
df['Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease of navigation in website, dtype: int64

# %% [markdown]
# Mostly people strongly agree that "ease in navigation of website" is very important.
#
# Very less people dis-agree with "Important of ease in navigation of website".

# %%
#Plotting countplot and piechart for the loading_processing_speed column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['loading_processing_speed'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['loading_processing_speed'])
df['loading_processing_speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: loading_processing_speed, dtype: int64

# %% [markdown]
# Mostly people agree followed by strongly agree with the importance of loading_processing_speed.

# %%
#Plotting countplot and piechart for the userfriendly_interface_website.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['userfriendly_interface_website'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['userfriendly_interface_website'])
df['userfriendly_interface_website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: userfriendly_interface_website, dtype: int64

# %% [markdown]
# We can see that most of our respondents strongly agree to the point that "userfriendly interface of the website" is very important.

# %%
#Plotting countplot and piechart for Convenient_pay_methods column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Convenient_pay_methods'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Convenient_pay_methods'])
df['Convenient_pay_methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: Convenient_pay_methods, dtype: int64

# %% [markdown]
# Many of the respondents strongly believe that if payment methods are convenient then it will be good for online shoppers.

# %%
#Plotting countplot and piechart for Trust_online_store_fulfill_itspart_oftransaction_intime column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Trust_online_store_fulfill_itspart_oftransaction_intime'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Trust_online_store_fulfill_itspart_oftransaction_intime'])
df['Trust_online_store_fulfill_itspart_oftransaction_intime'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: Trust_online_store_fulfill_itspart_oftransaction_intime, dtype: int64

# %% [markdown]
# Many of the respondents strongly trust that the online retail store will fulfill its part of the transaction at the stipulated time.

# %%
#Plotting countplot and piechart for Readiness_to_help_customers column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Readiness_to_help_customers'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Readiness_to_help_customers'])
df['Readiness_to_help_customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: Readiness_to_help_customers, dtype: int64

# %% [markdown]
# Most of Customers firmly believe that approach of "Readiness to help the customers always" is the most important concern.

# %%
#Plotting countplot and piechart for Guarantee_privacy_of_customers column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Guarantee_privacy_of_customers'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Guarantee_privacy_of_customers'])
df['Guarantee_privacy_of_customers'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: Guarantee_privacy_of_customers, dtype: int64

# %% [markdown]
# As we all know that privacy is the most vital thing as all the customers data like credit-card number, debit-card number, are stored in the retailers database, and customer believes on the company that it will not breach the private data policy.
#
# Our records also shows that most of customers strongly believe that online store must guarantee the privacy of the data of customers.

# %%
#Plotting countplot and piechart for Customer_support_availability_by_modes column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Customer_support_availability_by_modes'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Customer_support_availability_by_modes'])
df['Customer_support_availability_by_modes'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: Customer_support_availability_by_modes, dtype: int64

# %% [markdown]
# Most of the customers expect that their online store must provide the assistance to them through various modes like ("Email","Text messages","Phone Call").

# %%
#Plotting countplot and piechart for Monetary_benefits_online_shopping_discounts column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Monetary_benefits_online_shopping_discounts'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Monetary_benefits_online_shopping_discounts'])
df['Monetary_benefits_online_shopping_discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: Monetary_benefits_online_shopping_discounts, dtype: int64

# %% [markdown]
# Mostly of the customers are inclined towards the perks of monetary benefits while shopping in the forms of coupons,discount offers etc.

# %%
#Plotting countplot and piechart for Enjoyment_from_online_shopping column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Enjoyment_from_online_shopping'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Enjoyment_from_online_shopping'])
df['Enjoyment_from_online_shopping'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: Enjoyment_from_online_shopping, dtype: int64

# %% [markdown]
# Most people agree that they enjoy the online shopping.
#
# Many of respondents are also unconcerned about the enjoyment.
#
# Very few of them disagree with the fact of enjoyment while online shopping.

# %%
#Plotting countplot and piechart for onlineshopping_convenient_flexible column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['onlineshopping_convenient_flexible'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['onlineshopping_convenient_flexible'])
df['onlineshopping_convenient_flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: onlineshopping_convenient_flexible, dtype: int64

# %% [markdown]
# Mostly people strogly agree with onlie shopping is flexible and convenient

# %%
#Plotting countplot and piechart for Importance_return_policy_replacement_policy column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Importance_return_policy_replacement_policy'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Importance_return_policy_replacement_policy'])
df['Importance_return_policy_replacement_policy'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: Importance_return_policy_replacement_policy, dtype: int64

# %% [markdown]
# As we all know that replacement and return policy is very much important for a customer since if the product which he/she buyed didnt performing well then they can return it to the seller without any problem by giving proper reason of return of product.
#
# Most of the customers are agreeing with the fact that there must be customer friendly return or replacement policy must be present for the product.

# %%
#Plotting countplot and piechart for loyality_program_benefit_shopping_online column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['loyality_program_benefit_shopping_online'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['loyality_program_benefit_shopping_online'])
df['loyality_program_benefit_shopping_online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: loyality_program_benefit_shopping_online, dtype: int64

# %% [markdown]
# Mostly people strongly agree with "Loyalty program is benefit of online shopping"

# %%
#Plotting countplot and piechart for Quality_info_website_improves_satisfaction column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Quality_info_website_improves_satisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Quality_info_website_improves_satisfaction'])
df['Quality_info_website_improves_satisfaction'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: Quality_info_website_improves_satisfaction, dtype: int64

# %% [markdown]
# We all know that quality information about the product helps us to understand the product well and we can decide upon reading the details whether to go for the shopping or not.
#
# Customers are strongly agreeing with importance of the presence of the quality information present in the dashboard improves the satisfaction of the customers.

# %%
#Plotting countplot and piechart for Satisfaction_shopping_goodquality_website column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Satisfaction_shopping_goodquality_website'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Satisfaction_shopping_goodquality_website'])
df['Satisfaction_shopping_goodquality_website'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: Satisfaction_shopping_goodquality_website, dtype: int64

# %% [markdown]
# Mostly people strongly agree for deriving satisfaction while shopping on a good quality website or a application.

# %%
#Plotting countplot and piechart for benefit_derived_from_shopping_online_lead_users_satisfaction column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['benefit_derived_from_shopping_online_lead_users_satisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['benefit_derived_from_shopping_online_lead_users_satisfaction'])
df['benefit_derived_from_shopping_online_lead_users_satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: benefit_derived_from_shopping_online_lead_users_satisfaction, dtype: int64

# %% [markdown]
# We can see that from the plots that many customers believe that benefit derived from the online shopping leads to customer satisfaction.

# %%
#Plotting countplot and piechart for user_satisfaction_with_trust column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['user_satisfaction_with_trust'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['user_satisfaction_with_trust'])
df['user_satisfaction_with_trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: user_satisfaction_with_trust, dtype: int64

# %% [markdown]
# We can see that mostly people strongly agree with existence of user satisfaction with trust on the online seller.

# %%
#Plotting countplot and piechart for wide_variety_product_category column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['wide_variety_product_category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['wide_variety_product_category'])
df['wide_variety_product_category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: wide_variety_product_category, dtype: int64

# %% [markdown]
# We can see that many people agree with offering a wide variety of listed product in different category

# %%
#Plotting countplot and piechart for Complete_and_relevant_product_info column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Complete_and_relevant_product_info'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Complete_and_relevant_product_info'])
df['Complete_and_relevant_product_info'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: Complete_and_relevant_product_info, dtype: int64

# %% [markdown]
# Mostly people are strongly agreeing that there should be complete and relevant information of every products.

# %%
#Plotting countplot and piechart for Monetary_savings column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Monetary_savings'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Monetary_savings'])
df['Monetary_savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: Monetary_savings, dtype: int64

# %% [markdown]
# We can see that large amount of people strongly agree with "Monetary savings"

# %%
#Plotting countplot and piechart for Convenience_of_patronizing_online_retailer column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Convenience_of_patronizing_online_retailer'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Convenience_of_patronizing_online_retailer'])
df['Convenience_of_patronizing_online_retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: Convenience_of_patronizing_online_retailer, dtype: int64

# %% [markdown]
# We can see that people are agree with convenience of patronizing the online retailer.

# %%
#Plotting countplot and piechart for Sense_of_adventure column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Sense_of_adventure'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Sense_of_adventure'])
df['Sense_of_adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: Sense_of_adventure, dtype: int64

# %% [markdown]
# Some of people agree that shopping online gives you the sense of adventure and some of people are indifferent and dis-agree with this.

# %%
#Plotting countplot and piechart for Social_status_enhancement_by_shopping_retailer column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Social_status_enhancement_by_shopping_retailer'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Social_status_enhancement_by_shopping_retailer'])
df['Social_status_enhancement_by_shopping_retailer'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: Social_status_enhancement_by_shopping_retailer, dtype: int64

# %% [markdown]
# We can see from the above plots that there is some mixed kind of response on "Shopping on your preferred e-tailer enhances your social status",most of the respondent are not concerned about it,some of are strongly concerned about it.

# %%
#Plotting countplot and piechart for Gratification_feeling_favourite_retailer column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Gratification_feeling_favourite_retailer'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Gratification_feeling_favourite_retailer'])
df['Gratification_feeling_favourite_retailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: Gratification_feeling_favourite_retailer, dtype: int64

# %% [markdown]
# We can see from the above plots that there is some mixed kind of response on "Gratification feeling while shopping from the favourite retailer",most of the respondent are not concerned about it,some of very strongly concerned about it.

# %%
#Plotting countplot and piechart for Shopping_website_helps_you_fulfill_certainroles column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Shopping_website_helps_you_fulfill_certainroles'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Shopping_website_helps_you_fulfill_certainroles'])
df['Shopping_website_helps_you_fulfill_certainroles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: Shopping_website_helps_you_fulfill_certainroles, dtype: int64

# %% [markdown]
# We can see from the above plots that there is some mixed kind of response on "Shopping on the website helps you fulfill certain roles",most of the respondent are not concerned about it,some of are concerned about it.

# %%
#Plotting countplot and piechart for Value_for_money column.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
df['Value_for_money'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(df['Value_for_money'])
df['Value_for_money'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: Value_for_money, dtype: int64

# %% [markdown]
# All of us expect value for the money whenever we shop anything from anywhere.
#
# Here also the respondents are also stick to the value for money statement.

# %%
#Plotting countplot and piechart for online_retailer_shopped_from column.
plt.figure(figsize=(12,10))
sns.countplot(y="online_retailer_shopped_from", data=df)
df['online_retailer_shopped_from'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: online_retailer_shopped_from, dtype: int64

# %% [markdown]
# Most of the Customers have shopped from all ("Amazon","Flipkart","Paytm","Myntra","Snapdeal").

# %%
#Plotting countplot and piechart for easy_to_use_website_application column.
plt.figure(figsize=(12,10))
sns.countplot(y="easy_to_use_website_application", data=df)
df['easy_to_use_website_application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: easy_to_use_website_application, dtype: int64

# %% [markdown]
# Most of the Customers have agreed that all("Amazon","Flipkart","Paytm","Myntra","Snapdeal") these websites or applications are easy to use.

# %%
#Plotting countplot and piechart for Visual_appealing_webpage column.
plt.figure(figsize=(12,10))
sns.countplot(y="Visual_appealing_webpage", data=df)
df['Visual_appealing_webpage'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual_appealing_webpage, dtype: int64

# %% [markdown]
# There are two website/applications (Amazon.in, Flipkart.com) that visually good as per the customer analysis.

# %%
#Plotting countplot and piechart for wild_variety_product_offer column.
plt.figure(figsize=(12,10))
sns.countplot(y="wild_variety_product_offer", data=df)
df['wild_variety_product_offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: wild_variety_product_offer, dtype: int64

# %% [markdown]
# Only two websites/application (Amazon.in, Flipkart.com) have offers on wide variety of products.

# %%
#Plotting countplot and piechart for Complete_relevant_description_about_product column.
plt.figure(figsize=(12,10))
sns.countplot(y="Complete_relevant_description_about_product", data=df)
df['Complete_relevant_description_about_product'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete_relevant_description_about_product, dtype: int64

# %% [markdown]
# Only two websites/application (Amazon.in, Flipkart.com) have complete and relevant description of products.

# %%
#Plotting countplot and piechart for Fast loading_website_application column.
plt.figure(figsize=(12,10))
sns.countplot(y="Fast loading_website_application", data=df)
df['Fast loading_website_application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading_website_application, dtype: int64

# %% [markdown]
# We can see that most responsive and fast website is "Amazon.com","Paytm" followed by "Flipkart.com"
#
# Slowest website is the "Snapdeal.com".

# %%
#Plotting countplot and piechart for Reliability_of_website_application column.
plt.figure(figsize=(12,10))
sns.countplot(y="Reliability_of_website_application", data=df)
df['Reliability_of_website_application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability_of_website_application, dtype: int64

# %% [markdown]
# We can see that Amazon.in is more reliable followed by Paytm.com, Flipkart.com and Myntra.com.

# %%
#Plotting countplot and piechart for Quickness_shopping column.
plt.figure(figsize=(12,10))
sns.countplot(y="Quickness_shopping", data=df)
df['Quickness_shopping'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness_shopping, dtype: int64

# %% [markdown]
# Amazon.in website or application has the quickness to complete purchase followed by Flipkart.com and Paytm.com.

# %%
#Plotting countplot and piechart for Availability_of_payment_options column.
plt.figure(figsize=(12,10))
sns.countplot(y="Availability_of_payment_options", data=df)
df['Availability_of_payment_options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability_of_payment_options, dtype: int64

# %% [markdown]
# Amazon.in and Flipkart.com have more payment options rather than other online platforms.

# %%
#Plotting countplot and piechart for speedy_order_delivery column.
plt.figure(figsize=(12,10))
sns.countplot(y="speedy_order_delivery", data=df)
df['speedy_order_delivery'].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: speedy_order_delivery, dtype: int64

# %% [markdown]
# We can see that "Amazon.com" delivers the product fastly followed by the "Flipkart.com".

# %%
#Plotting countplot and piechart for Privacy_of_customers column.
plt.figure(figsize=(12,10))
sns.countplot(y="Privacy_of_customers", data=df)
df['Privacy_of_customers'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy_of_customers, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" has more privacy for the customers' information followed by Flipkart.com.

# %%
#Plotting countplot and piechart for security_of_customer_fin_info column.
plt.figure(figsize=(12,10))
sns.countplot(y="security_of_customer_fin_info", data=df)
df['security_of_customer_fin_info'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: security_of_customer_fin_info, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" has more security of customer financial information followed by "Flipkart.com".

# %%
#Plotting countplot and piechart for Perceived_trustworthiness column.
plt.figure(figsize=(12,10))
sns.countplot(y="Perceived_trustworthiness", data=df)
df['Perceived_trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived_trustworthiness, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" has perceived trustworthiness followed by "Flipkart.com".

# %%
#Plotting countplot and piechart for Presence_onlin_assist_multichannel column.
plt.figure(figsize=(12,10))
sns.countplot(y="Presence_onlin_assist_multichannel", data=df)
df['Presence_onlin_assist_multichannel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence_onlin_assist_multichannel, dtype: int64

# %% [markdown]
# We can see that "Amazon.in", "Flipkart.com", "Myntra.com" and "Snapdeal.com" have online assistance through multi channels.

# %%
#Plotting countplot and piechart for Longer_time_to_get_logged_in column.
plt.figure(figsize=(12,10))
sns.countplot(y="Longer_time_to_get_logged_in", data=df)
df['Longer_time_to_get_logged_in'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer_time_to_get_logged_in, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" have longer time to get logged in followed by "Paytm.com" then "Myntra.com" then "Flipkart.com".

# %%
#Plotting countplot and piechart for long_tim_displ_graphics_photos column.
plt.figure(figsize=(12,10))
sns.countplot(y="long_tim_displ_graphics_photos", data=df)
df['long_tim_displ_graphics_photos'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: long_tim_displ_graphics_photos, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" has longer time in displaying graphics and photos followed by "Myntra.com", "Snapdeal.com".

# %%
#Plotting countplot and piechart for late_decl_of_price column.
plt.figure(figsize=(12,10))
sns.countplot(y="late_decl_of_price", data=df)
df['late_decl_of_price'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: late_decl_of_price, dtype: int64

# %% [markdown]
# We can see that "Myntra.com" have declared the prices of the products very late followed by "Paytm.com", "Snapdeal.com" and "Flipkart.com".

# %%
#Plotting countplot and piechart for Longer_pag_load_tim column.
plt.figure(figsize=(12,10))
sns.countplot(y="Longer_pag_load_tim", data=df)
df['Longer_pag_load_tim'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer_pag_load_tim, dtype: int64

# %% [markdown]
# We can see that "Myntra.com" and "Paytm.com" takes more time to load the page followed by "Flipkart.com" and "Snapdeal.com".

# %%
#Plotting countplot and piechart for Constraint_on_mostproducts_payment column.
plt.figure(figsize=(12,10))
sns.countplot(y="Constraint_on_mostproducts_payment", data=df)
df['Constraint_on_mostproducts_payment'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Constraint_on_mostproducts_payment, dtype: int64

# %% [markdown]
# We can clearly see from the plot that "Snapdeal" has constraints on payment methods for many products followed by "Amazon".
#
# Myntra and snapdeal are open to different payment methods.

# %%
#Plotting countplot and piechart for Long_del_period column.
plt.figure(figsize=(12,10))
sns.countplot(y="Long_del_period", data=df)
df['Long_del_period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Long_del_period, dtype: int64

# %% [markdown]
# From the above data given by the respondents we can clearly say that most quickly delivering website is 'Myntra'
#
# From the data ,most lately delivering website is "Paytm".
#
# Flipkart and Amazon both deliver the product on average time.

# %%
#Plotting countplot and piechart for Website_&_application_change column.
plt.figure(figsize=(12,10))
sns.countplot(y="Website_&_application_change", data=df)
df['Website_&_application_change'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Website_&_application_change, dtype: int64

# %% [markdown]
# We can see that "Amazon.in" is likely to change design in website or application then "Paytm.com".
#
# Other platforms are very less likely to change the designs of website or application.

# %%
#Plotting countplot and piechart for Frequent_disruption_pageschanging column.
plt.figure(figsize=(12,10))
sns.countplot(y="Frequent_disruption_pageschanging", data=df)
df['Frequent_disruption_pageschanging'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent_disruption_pageschanging, dtype: int64

# %% [markdown]
# From the above plot, we can see that "Amazon.in" has frequent disruption while moving from one pagr to another followed by "Myntra.com", "Snapdeal.com", "Paytm.com" and "Flipkart.com"

# %%
#Plotting countplot and piechart for Efficient_website column.
plt.figure(figsize=(12,10))
sns.countplot(y="Efficient_website", data=df)
df['Efficient_website'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Efficient_website, dtype: int64

# %% [markdown]
# From the polls we can say that most efficient website is "Amazon" followed by "Flipkart".
#
# Most inefficient website is "snapdeal".

# %%
#Plotting countplot and piechart for Online_retailer_reccom column.
plt.figure(figsize=(12,10))
sns.countplot(y="Online_retailer_reccom", data=df)
df['Online_retailer_reccom'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Online_retailer_reccom, dtype: int64

# %% [markdown]
# We can see that the best choice of most of the people is "Amazon" followed by "Flipkart" & "Myntra".
#
# Very few people will recommend "Snapdeal" & "Paytm".

# %% [markdown]
# # Conclusions/Insights

# %% [markdown]
# - Amazon.in is the peoples favorite choice for the online shopping ,since it is offering the sales of its products with various additional benefits like “Fastest delivering orders", "Fastest loading and responsive website", "More products are available for any section of item” etc.Flipkart is also performing good but it comes after the Amazon.
#
# - Least rated online retailer companies are Snapdeal.com and Paytm.com ,very less proportion of the population are following them due to the various reasons like “Very long delivery periods", "Slow loading website", "Less varieties of the products are listed on them” etc.

# %% [markdown]
# - When customers are satisfied with a company or service, there is a high possibility that they will share their experience with other people Therefore it is crucial for E-commerce to take into account their customer satisfaction because this will retain customer loyalty as well as attract potential customers.
#
# - To conclude, having the right customer retention strategy will keep sellers company growing if they know how to take advantage of it. Then customers will find their way back and continue buying stuff from the best company.
